# %% [markdown]
# ### 首先先載入相關的套件

# %%
import requests

# %% [markdown]
# ### 透過```requests.get()```的方式，可以直接像目標網站發送請求，網站回傳的結果便會儲存在變數```resp```中。

# %%
url = 'https://www.dcard.tw/f'
header = {'user-agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'}

resp = requests.get(url, headers=header)

# %% [markdown]
# ### 透過status_code來查看回傳的狀態種類。
#
# - ### 1xx: 訊息，代表請求已被接受，需要繼續處理。
#     - 例如：102，伺服器已經收到請求並正在處理。這類型的訊息並不常出現。
# - ### 2xx: 成功，代表請求已成功被伺服器接收、理解、並接受。
#     - 例如：200，請求已成功，請求的內容隨此回應返回。
# - ### 3xx: 重新導向，代表需要用戶端採取進一步的操作才能完成請求。
#     - 例如：305，被請求的資源必須通過指定的代理才能被存取。
# - ### 4xx: 用戶端錯誤，代表了用戶端看起來可能發生了錯誤，妨礙了伺服器的處理。
#     - 例如：404，請求失敗，請求所希望得到的資源未被在伺服器上發現，但允許用戶的後續請求。
# - ### 5xx: 伺服器錯誤，代表服器無法完成明顯有效的請求。
#     - 例如：500，伺服器遇到意外狀況，無法完成請求的處理。

# %%
resp.status_code
# Out:
# 200

# %% [markdown]
# ### 查看抓下來的內容

# %%
resp.text
# Out:
# '<!DOCTYPE html><html lang="zh-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https://schema.org/WebSite"><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1"/><meta name="apple-mobile-web-app-status-bar-style" content="default"/><link rel="stylesheet" type="text/css" href="https://fonts.googleapis.com/css?family=Roboto:400,300"/><meta name="application-name" content="Dcard"/><meta name="apple-itunes-app" content="app-id=951353454"/><meta name="theme-color" content="#006aa6"/><meta name="mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta name="supported-color-schemes" content="light"/><meta property="fb:app_id" content="211628828926493"/><meta property="fb:pages" content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764"/><meta property="al:ios:app_store_id" content="951353454"/><meta property="al:ios:app_name" content="Dcard"/><meta property="al:android:package" content="com.sparkslab.dcardreader"/><meta property="al:android:app_name" content="Dcard"/><link rel="manifest" href="/_next/static/manifest.json"/><link rel="icon" type="image/png" sizes="16x16" href="/_next/static/images/icon-16-1daa7474e5fe761a7239d12c56b88680.png"/><link rel="icon" type="image/png" sizes="24x24" href="/_next/static/images/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png"/><link rel="icon" type="image/png" sizes="32x32" href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><link rel="icon" type="image/png" sizes="192x192" href="/_next/static/images/icon-192-49149beb434e1f6bccac918f6608564c.png"/><link rel="apple-touch-icon" type="image/png" sizes="57x57" href="/_next/static/images/icon-57-c95fcd930b41dbc6de0495348939582f.png"/><link rel="apple-touch-icon" type="image/png" sizes="72x72" href="/_next/static/images/icon-72-69b64cb9aadc811dce34ea6ac772cd8f.png"/><link rel="apple-touch-icon" type="image/png" sizes="76x76" href="/_next/static/images/icon-76-67203a784694f8378d2f51f24970e2f7.png"/><link rel="apple-touch-icon" type="image/png" sizes="114x114" href="/_next/static/images/icon-114-c58f911deb58868e8cc68ea1e09cc688.png"/><link rel="apple-touch-icon" type="image/png" sizes="120x120" href="/_next/static/images/icon-120-f3ada61716c0cc460c2cbe72b18fb9b4.png"/><link rel="apple-touch-icon" type="image/png" sizes="144x144" href="/_next/static/images/icon-144-679d873aa4b58f1117915545d3fdfa1d.png"/><link rel="apple-touch-icon" type="image/png" sizes="152x152" href="/_next/static/images/icon-152-b7ec982f1f49f590c97611e0e5e9f7f3.png"/><link rel="apple-touch-icon" type="image/png" sizes="180x180" href="/_next/static/images/icon-180-2665760e1b88b5af7a3cfbdc532bae20.png"/><link rel="shortcut icon" type="image/png" href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n      new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n      j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n      \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n      })(window,document,\'script\',\'dataLayer\',\'GTM-TWLTW4M\');</script><meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1"/><meta charSet="utf-8"/><meta name="description" content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"/><meta property="og:description" content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"/><meta property="og:type" content="website"/><meta property="twitter:description" content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"/><meta name="image" itemProp="image" content="https://www.dcard.tw/images/landing.png"/><meta property="og:image" content="https://www.dcard.tw/images/landing.png"/><meta property="og:image:secur ...

# %%
type(resp.text)
# Out:
# str

# %% [markdown]
# ### 從上面可以得知，```requests```已經幫我們把整個網頁抓下來，並存成```str```的格式，但是這種格式不利我們選出想要的資料，這時候就換```BeautifulSoup```上場了：
#
# ### 一樣先載入模組

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# ### lxml是一種html的解析器(parser)，速度較Python內建的html.parser快，使用前需先下載：
# ```bash
# pip install lxml
# ```

# %%
html = resp.text
soup = BeautifulSoup(html, "lxml")

# %%
# %timeit BeautifulSoup(html, "lxml")
# %timeit BeautifulSoup(html, "html.parser")
# Out:
# 29 ms ± 2.04 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 38.6 ms ± 1.12 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ###  透過```prettify()```將結果排版後輸出

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="zh-TW">\n <head itemscope="" itemtype="https://schema.org/WebSite" prefix="og: http://ogp.me/ns#">\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/>\n  <meta content="default" name="apple-mobile-web-app-status-bar-style"/>\n  <link href="https://fonts.googleapis.com/css?family=Roboto:400,300" rel="stylesheet" type="text/css"/>\n  <meta content="Dcard" name="application-name"/>\n  <meta content="app-id=951353454" name="apple-itunes-app"/>\n  <meta content="#006aa6" name="theme-color"/>\n  <meta content="yes" name="mobile-web-app-capable"/>\n  <meta content="yes" name="apple-mobile-web-app-capable"/>\n  <meta content="light" name="supported-color-schemes"/>\n  <meta content="211628828926493" property="fb:app_id"/>\n  <meta content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764" property="fb:pages"/>\n  <meta content="951353454" property="al:ios:app_store_id"/>\n  <meta content="Dcard" property="al:ios:app_name"/>\n  <meta content="com.sparkslab.dcardreader" property="al:android:package"/>\n  <meta content="Dcard" property="al:android:app_name"/>\n  <link href="/_next/static/manifest.json" rel="manifest"/>\n  <link href="/_next/static/images/icon-16-1daa7474e5fe761a7239d12c56b88680.png" rel="icon" sizes="16x16" type="image/png"/>\n  <link href="/_next/static/images/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png" rel="icon" sizes="24x24" type="image/png"/>\n  <link href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png" rel="icon" sizes="32x32" type="image/png"/>\n  <link href="/_next/static/images/icon-192-49149beb434e1f6bccac918f6608564c.png" rel="icon" sizes="192x192" type="image/png"/>\n  <link href="/_next/static/images/icon-57-c95fcd930b41dbc6de0495348939582f.png" rel="apple-touch-icon" sizes="57x57" type="image/png"/>\n  <link href="/_next/static/images/icon-72-69b64cb9aadc811dce34ea6ac772cd8f.png" rel="apple-touch-icon" sizes="72x72" type="image/png"/>\n  <link href="/_next/static/images/icon-76-67203a784694f8378d2f51f24970e2f7.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/>\n  <link href="/_next/static/images/icon-114-c58f911deb58868e8cc68ea1e09cc688.png" rel="apple-touch-icon" sizes="114x114" type="image/png"/>\n  <link href="/_next/static/images/icon-120-f3ada61716c0cc460c2cbe72b18fb9b4.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/>\n  <link href="/_next/static/images/icon-144-679d873aa4b58f1117915545d3fdfa1d.png" rel="apple-touch-icon" sizes="144x144" type="image/png"/>\n  <link href="/_next/static/images/icon-152-b7ec982f1f49f590c97611e0e5e9f7f3.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/>\n  <link href="/_next/static/images/icon-180-2665760e1b88b5af7a3cfbdc532bae20.png" rel="apple-touch-icon" sizes="180x180" type="image/png"/>\n  <link href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png" rel="shortcut icon" type="image/png"/>\n  <script>\n   (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n      new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n      j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n      \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n      })(window,document,\'script\',\'dataLayer\',\'GTM-TWLTW4M\');\n  </script>\n  <meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/>\n  <meta charset="utf-8"/>\n  <meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" name="description"/>\n  <meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" property="og:description"/>\n  <meta content="website" property="og:type"/>\n  <meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" property="twitter:description"/>\n  <meta content="https://w ...

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ### 經過轉換，原本是str的HTML，已經被轉換成bs4的物件。下面列出一些bs4物件的屬性和方法

# %%
soup.title
# Out:
# <title>Dcard</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.string
# Out:
# 'Dcard'

# %%
soup.a
# Out:
# <a class="sc-1h3w01r-0 BYkrm" href="/f" title="Dcard"><img alt="Dcard" class="ezgous-0 ktvxUR" src="/_next/static/images/logo-6c547910a47669647856d4c9cc62f0ba.svg"/></a>

# %%
soup.find('a')
# Out:
# <a class="sc-1h3w01r-0 BYkrm" href="/f" title="Dcard"><img alt="Dcard" class="ezgous-0 ktvxUR" src="/_next/static/images/logo-6c547910a47669647856d4c9cc62f0ba.svg"/></a>

# %% [markdown]
# ### 抓出超連結中的網址

# %%
a_list = soup.find_all("a")
for i in range(20):
    print(a_list[i].get('href'))
# Out:
# /f
# /signup?redirect=%2Ff
# None
# /forum/all
# /forum/popular
# /goods
# /f
# /f?pessoal=true
# /f/mood/p/233377179
# /f/funny/p/233378786
# /f/funny/p/233377448
# /f/funny/p/233377001
# /f/makeup/p/233377097
# /f/relationship/p/233377014
# /f/funny/p/233375983
# /f/relationship/p/233377675
# /f/youtuber/p/233377693
# /f/girl/p/233376121
# /f/2019_ncov/p/233378302
# /f/trending/p/233377490

# %% [markdown]
# ### 可以設定參數，來查找特定tag
#
# ### 列出Dard十大熱門文章及其網址

# %%
soup.find_all('a', class_='sc-1v1d5rx-4 cJzlcl')
# Out:
# [<a class="sc-1v1d5rx-4 cJzlcl" href="/f/mood/p/233377179"><span>「妹妹，要不要一起玩？」</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/funny/p/233378786"><span>驚！馬桶驚見⋯⋯</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/funny/p/233377448"><span>看到我弟如何幹話回覆直銷</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/funny/p/233377001"><span>最後一隻差點往生</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/makeup/p/233377097"><span>我的眉毛之路</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/relationship/p/233377014"><span>女朋友越來越沒引力</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/funny/p/233375983"><span>感覺被nasa冒犯：（</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/relationship/p/233377675"><span>這麼早結婚不會覺得失去什麼嗎？或是少了很多樂趣嗎？</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/youtuber/p/233377693"><span>原來胡椒不只打排球，棒球也打</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/girl/p/233376121"><span>路上神經病瘋子真的很多，好可怕😭 (台北車站-中山站周遭)</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/2019_ncov/p/233378302"><span>北部大學學生確診</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/trending/p/233377490"><span>彭博：全球恐剩台灣學生仍「全面到校上課」　驚人原因曝光</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/fitness/p/233377425"><span>粉頭進來看一下</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/weight_loss/p/233377748"><span>減肥20公斤心得</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/2019_ncov/p/233377957"><span>#更 師大化學確診 （轉）案例修課地點</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/girl/p/233380455"><span>昨天完成了真空吸引術人工流產，再見我的第二個寶寶。</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/food/p/233379525"><span>照片真的會影響銷量！</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/funny/p/233378661"><span>男友用金庸跟我吵架</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/2019_ncov/p/233378856"><span>愚人節請勿進行疫情惡作劇！</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/food/p/233376619"><span>有推薦好吃的冰塊嗎？（更）</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/relationship/p/233378064"><span>約炮的人不要再隱瞞另一半</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/2019_ncov/p/233377453"><span>厲害了! 英國人躲避封城禁令的辦法!</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/entertainer/p/233376526"><span>這追星妹子講話真的壞...</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/makeup/p/233377999"><span>不要玩小孩阿阿？？？？？</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/exam/p/233377168"><span>狂賀...</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/funny/p/233378266"><span>飲料店打工的那些趣事</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/vehicle/p/233378656"><span>沒品舅舅一直偷騎我車</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/food/p/233379974"><span>滿滿的大薯</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/girl/p/233376631"><span>#噁圖慎入 #一個很愛漂亮的女生腳卻變成這樣...😭</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/buyonline/p/233376371"><span>#二更#更#黑特 第一次買潘朵拉送禮就買到假貨？</span></a>]

# %%
title = soup.find_all('a', class_='sc-1v1d5rx-4 cJzlcl')
for i in range(10):
    print(title[i].string)
    print("文章ID:" + title[i].get('href').split('/')[-1])
    print("文章網址： https://www.dcard.tw{}".format(title[i].get('href')))
# Out:
# 「妹妹，要不要一起玩？」
# 文章ID:233377179
# 文章網址： https://www.dcard.tw/f/mood/p/233377179
# 驚！馬桶驚見⋯⋯
# 文章ID:233378786
# 文章網址： https://www.dcard.tw/f/funny/p/233378786
# 看到我弟如何幹話回覆直銷
# 文章ID:233377448
# 文章網址： https://www.dcard.tw/f/funny/p/233377448
# 最後一隻差點往生
# 文章ID:233377001
# 文章網址： https://www.dcard.tw/f/funny/p/233377001
# 我的眉毛之路
# 文章ID:233377097
# 文章網址： https://www.dcard.tw/f/makeup/p/233377097
# 女朋友越來越沒引力
# 文章ID:233377014
# 文章網址： https://www.dcard.tw/f/relationship/p/233377014
# 感覺被nasa冒犯：（
# 文章ID:233375983
# 文章網址： https://www.dcard.tw/f/funny/p/233375983
# 這麼早結婚不會覺得失去什麼嗎？或是少了很多樂趣嗎？
# 文章ID:233377675
# 文章網址： https://www.dcard.tw/f/relationship/p/233377675
# 原來胡椒不只打排球，棒球也打
# 文章ID:233377693
# 文章網址： https://www.dcard.tw/f/youtuber/p/233377693
# 路上神經病瘋子真的很多，好可怕😭 (台北車站-中山站周遭)
# 文章ID:233376121
# 文章網址： https://www.dcard.tw/f/girl/p/233376121

# %% [markdown]
# ### API方式示範：Dcard

# %%
url = "https://www.dcard.tw/f/mood/p/233377179"
resp = requests.get(url)
resp.status_code
# Out:
# 200

# %%
html = resp.text
html = BeautifulSoup(html, "lxml")

# %%
html.find_all("div", class_="sc-1wrppqn-3 fIdNgN")
# Out:
# [<div class="sc-1wrppqn-3 fIdNgN">國立臺灣大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">中國醫藥大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立雲林科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立雲林科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立臺灣大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">中國醫藥大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">鯊魚養殖戶</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">新北倉鼠系</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">中國文化大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">這則回應已被刪除</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">高苑科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">僑光科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立交通大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">耕莘健康管理專科學校</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">致理科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">輔英科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立中央大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">高雄醫學大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立政治大學 法律研究所</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">臺北城市科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立中正大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">致理科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">長榮大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立臺北商業大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">朝陽科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">健行科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">朝陽科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立臺中科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">長榮大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">輔仁大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立臺中科技大學 應用英語系</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">麻瓜燉雞</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立高雄科技大學</div>]

# %% [markdown]
# ### 使用api去資料

# %%
article_id = "233377179" 
dcard_api = "https://www.dcard.tw/service/api/v2/posts/{}/comments".format(article_id)

header = {'user-agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'}
resp = requests.get(dcard_api, headers=header)
print(resp.url)
print()
print(resp.text)
# Out:
# https://www.dcard.tw/service/api/v2/posts/233377179/comments
#
# [{"id":"1f4c8e1f-a48f-4d9a-8b7f-7f88fda4c847","anonymous":true,"postId":233377179,"createdAt":"2020-03-30T19:53:32.993Z","updatedAt":"2020-03-30T19:53:32.993Z","floor":1,"content":"妳和你哥都辛苦了  加油","likeCount":4783,"withNickname":false,"hiddenByAuthor":false,"meta":{},"gender":"M","school":"國立雲林科技大學","host":false,"reportReason":"","mediaMeta":[],"hidden":false,"inReview":false,"reportReasonText":"","isSuspiciousAccount":false,"postAvatar":""},{"id":"7c91dc95-84a6-4679-b04b-cd9d030fd7b6","anonymous":true,"postId":233377179,"createdAt":"2020-03-30T20:15:39.247Z","updatedAt":"2020-03-31T23:37:02.221Z","floor":2,"content":"終於有正常的文章\n\n\n第一次有這麼多愛心@@\nB130","likeCount":7108,"withNickname":false,"hiddenByAuthor":false,"meta":{},"gender":"M","school":"國立臺灣大學","host":false,"reportReason":"","mediaMeta":[],"hidden":false,"inReview":false,"reportReasonText":"","isSuspiciousAccount":false,"postAvatar":""},{"id":"8a172145-4c36-4859-8c4c-9a0284e658ca","anonymous":true,"postId":233377179,"createdAt":"2020-03-30T20:24:05.504Z","updatedAt":"2020-03-30T20:24:05.504Z","floor":3,"content":"真是一個滿分的妹妹………","likeCount":4808,"withNickname":false,"hiddenByAuthor":false,"meta":{},"gender":"M","school":"中國醫藥大學","host":false,"reportReason":"","mediaMeta":[],"hidden":false,"inReview":false,"reportReasonText":"","isSuspiciousAccount":false,"postAvatar":""},{"id":"cdd73c45-2a6d-443e-9cdc-d8cefca1120e","anonymous":false,"postId":233377179,"createdAt":"2020-03-30T21:30:37.743Z","updatedAt":"2020-03-30T21:30:37.743Z","floor":4,"content":"都辛苦了\n你是個很好的妹妹\n別給自己太大的壓力\n感覺妳已經很棒了","likeCount":584,"withNickname":true,"hiddenByAuthor":false,"meta":{},"gender":"F","school":"鯊魚養殖戶","department":"chin_yu","host":false,"reportReason":"","mediaMeta":[],"hidden":false,"inReview":false,"reportReasonText":"","isSuspiciousAccount":false,"postAvatar":""},{"id":"a6134ff7-5421-49c8-a0ca-e14a82f899f3","anonymous":false,"postId":233377179,"createdAt":"2020-03-30T21:34:10.255Z","updatedAt":"2020-03-30T21:34:10.255Z","floor":5,"content":"辛苦了，你很棒","likeCount":162,"withNickname":true,"hiddenByAuthor":false,"meta":{},"gender":"F","school":"新北倉鼠系","department":"milk_0711","host":false,"reportReason":"","mediaMeta":[],"hidden":false,"inReview":false,"reportReasonText":"","isSuspiciousAccount":false,"postAvatar":""},{"id":"45093d81-a1a8-44a4-9cee-56faf333a103","anonymous":true,"postId":233377179,"createdAt":"2020-03-30T23:32:35.230Z","updatedAt":"2020-03-30T23:32:35.230Z","floor":6,"content":"你是一個好妹妹，辛苦你了，要加油唷","likeCount":182,"withNickname":false,"hiddenByAuthor":false,"meta":{},"gender":"F","school":"中國文化大學","host":false,"reportReason":"","mediaMeta":[],"hidden":false,"inReview":false,"reportReasonText":"","isSuspiciousAccount":false,"postAvatar":""},{"id":"b8bd2d94-8643-431d-9b60-3ba0b924f020","anonymous":false,"postId":233377179,"createdAt":"2020-03-31T00:05:07.517Z","updatedAt":"2020-03-31T00:05:07.517Z","floor":7,"withNickname":false,"hiddenByAuthor":true,"meta":{},"host":false,"reportReason":"","mediaMeta":[],"hidden":true,"inReview":false,"reportReasonText":"","isSuspiciousAccount":false,"postAvatar":""},{"id":"b2dcaebe-99ee-4930-aec9-11d5aa2d43b7","anonymous":true,"postId":233377179,"createdAt":"2020-03-31T00:05:34.162Z","updatedAt":"2020-03-31T00:05:34.162Z","floor":8,"content":"辛苦妳了，妳哥哥也是\n\n加油加油努力過好每一天💪💪","likeCount":124,"withNickname":false,"hiddenByAuthor":false,"meta":{},"gender":"M","school":"高苑科技大學","host":false,"reportReason":"","mediaMeta":[],"hidden":false,"inReview":false,"reportReasonText":"","isSuspiciousAccount":false,"postAvatar":""},{"id":"9980882a-4621-4bf9-9261-b71d2cc1e3f4","anonymous":false,"postId":233377179,"createdAt":"2020-03-31T00:43:26.471Z","updatedAt":"2020-03-31T00:43:26.471Z","floor":9,"content":"你很好！是哥哥的天使！更是哥哥的全部","likeCount":234,"withNickname":true,"hiddenByAuthor":false,"meta":{},"gender":"M","school":"僑光科技大學","department":"okevin_d","host":false,"reportReason":"","mediaMeta":[],"hidden":false,"inReview":false,"reportReasonText":"","isSuspiciousAccoun ...

# %% [markdown]
# ### 用JSON的方式呈現

# %%
resp.json()
# Out:
# [{'id': '1f4c8e1f-a48f-4d9a-8b7f-7f88fda4c847',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T19:53:32.993Z',
#   'updatedAt': '2020-03-30T19:53:32.993Z',
#   'floor': 1,
#   'content': '妳和你哥都辛苦了  加油',
#   'likeCount': 4783,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立雲林科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '7c91dc95-84a6-4679-b04b-cd9d030fd7b6',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T20:15:39.247Z',
#   'updatedAt': '2020-03-31T23:37:02.221Z',
#   'floor': 2,
#   'content': '終於有正常的文章\n\n\n第一次有這麼多愛心@@\nB130',
#   'likeCount': 7108,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立臺灣大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '8a172145-4c36-4859-8c4c-9a0284e658ca',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T20:24:05.504Z',
#   'updatedAt': '2020-03-30T20:24:05.504Z',
#   'floor': 3,
#   'content': '真是一個滿分的妹妹………',
#   'likeCount': 4808,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '中國醫藥大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'cdd73c45-2a6d-443e-9cdc-d8cefca1120e',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T21:30:37.743Z',
#   'updatedAt': '2020-03-30T21:30:37.743Z',
#   'floor': 4,
#   'content': '都辛苦了\n你是個很好的妹妹\n別給自己太大的壓力\n感覺妳已經很棒了',
#   'likeCount': 584,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '鯊魚養殖戶',
#   'department': 'chin_yu',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'a6134ff7-5421-49c8-a0ca-e14a82f899f3',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T21:34:10.255Z',
#   'updatedAt': '2020-03-30T21:34:10.255Z',
#   'floor': 5,
#   'content': '辛苦了，你很棒',
#   'likeCount': 162,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '新北倉鼠系',
#   'department': 'milk_0711',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '45093d81-a1a8-44a4-9cee-56faf333a103',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T23:32:35.230Z',
#   'updatedAt': '2020-03-30T23:32:35.230Z',
#   'floor': 6,
#   'content': '你是一個好妹妹，辛苦你了，要加油唷',
#   'likeCount': 182,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '中國文化大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'b8bd2d94-8643-431d-9b60-3ba0b924f020',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T00:05:07.517Z',
#   'updatedAt': '2020-03-31T00:05:07.517Z',
#   'floor': 7,
#   'withNickname': False,
#   'hiddenByAuthor': True,
#   'meta': {},
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': True,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'b2dcaebe-99ee-4930-aec9-11d5aa2d43b7',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T00:05:34.162Z',
#   'updatedAt': '2020-03-31T00:05:34.162Z',
#   'floor': 8,
#   'content': '辛苦妳了，妳哥哥也是\n\n加油加油努力過好每一天💪💪',
#   'likeCount': 124,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '高苑科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '9980882a-4621-4bf9-9261-b71d2cc1e3f4',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T00:43:26.471Z',
#   'updatedAt': '2020-03-31T00:43:26.471Z',
#   'floor': 9,
#   'content': '你很好！是哥哥的天使！更是哥哥的全部',
#   'likeCount': 234,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '僑光科技大學',
#   'department': 'okevin_d',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'aa00cdef-6fad-4269-839d-29ae439bd2cb',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T01:14:13.510Z',
#   'updatedAt': '2020-03-31T01:14:13.510Z',
#   'floor': 10,
#   'content': '我姐也是智能不足\n辛苦了～',
#   'likeCount': 129,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立交通大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '2595dd43-d933-46fe-8edb-0cf1b780fdf5',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T01:37:55.039Z',
#   'updatedAt': '2020-03-31T01:37:55.039Z',
#   'floor': 11,
#   'content': '辛苦妳了 妳最棒了QQ',
#   'likeCount': 60,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '耕莘健康管理專科學校',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'e94ae3ca-3666-43f6-953d-09be8a83d8fb',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T01:45:55.917Z',
#   'updatedAt': '2020-03-31T01:45:55.917Z',
#   'floor': 12,
#   'content': '哥哥一定很謝謝有你這個好妹妹❤️',
#   'likeCount': 99,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '致理科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'e161efd9-ac2e-4a65-994c-208024f64886',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T01:46:53.437Z',
#   'updatedAt': '2020-03-31T01:46:53.437Z',
#   'floor': 13,
#   'content': '真的你好棒！你也是一個很善良的人喔 跟你哥哥果然是最好的夥伴呢o(≧v≦)o',
#   'likeCount': 109,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '輔英科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '5bf9b416-1d24-4a30-943a-23bf125ecc66',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T02:01:54.018Z',
#   'updatedAt': '2020-03-31T02:01:54.018Z',
#   'floor': 14,
#   'content': '都辛苦了♡你真的很棒！',
#   'likeCount': 48,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立中央大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'b21f10f9-98ef-4fa8-a401-76c1ca07bbc8',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T02:13:22.608Z',
#   'updatedAt': '2020-03-31T02:13:22.608Z',
#   'floor': 15,
#   'content': '你是個好妹妹',
#   'likeCount': 42,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '高雄醫學大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'a33a29fc-c7f0-42b2-b043-5e0be7ead88b',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T02:23:10.263Z',
#   'updatedAt': '2020-03-31T02:23:10.263Z',
#   'floor': 16,
#   'content': '文筆好好\n妳是一個很棒的妹妹\n也謝謝妳的這篇文章\n讓人覺得心裡暖洋洋的\n妳們都是心地善良的小天使',
#   'likeCount': 272,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立政治大學',
#   'department': '法律研究所',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '1953b3a7-e185-481f-a33f-b056b1a1b874',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T02:40:51.653Z',
#   'updatedAt': '2020-03-31T02:40:51.653Z',
#   'floor': 17,
#   'content': '加油',
#   'likeCount': 23,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '臺北城市科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '13a14d36-225b-4b41-8424-599878a1cc53',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T02:52:05.512Z',
#   'updatedAt': '2020-03-31T02:52:05.512Z',
#   'floor': 18,
#   'content': '老闆⋯⋯我的早餐你怎麼加那麼多生洋蔥⋯⋯',
#   'likeCount': 175,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立中正大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '7703069e-527b-4b95-bcaf-87306dbc1d62',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:01:44.512Z',
#   'updatedAt': '2020-03-31T03:01:44.512Z',
#   'floor': 19,
#   'content': '只是喝杯奶茶怎麼沒味道...\n啊抱歉我眼淚滴太多了',
#   'likeCount': 146,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '致理科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '189548ff-c2d1-4bb0-be5c-ccdfaf555c9e',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:02:08.444Z',
#   'updatedAt': '2020-03-31T03:02:08.444Z',
#   'floor': 20,
#   'content': '看到標題以為是母湯的',
#   'likeCount': 112,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '長榮大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'd5002f85-36e8-4623-99c6-f211789260a2',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:07:17.609Z',
#   'updatedAt': '2020-03-31T03:07:17.609Z',
#   'floor': 21,
#   'content': '我的課本上都是我的淚😭',
#   'likeCount': 58,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立臺北商業大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'c36ad4f0-ae74-41d1-8523-092f07177879',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:07:17.884Z',
#   'updatedAt': '2020-03-31T03:07:17.884Z',
#   'floor': 22,
#   'content': '（抱',
#   'likeCount': 20,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '朝陽科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'b2bebbcf-f4c2-4684-9214-565311914b45',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:11:30.775Z',
#   'updatedAt': '2020-03-31T03:11:30.775Z',
#   'floor': 23,
#   'content': '好暖心喔！反而是當媽媽的怎麼都會把情緒發洩小孩身上 很舒壓？媽的！因為我也是被媽媽時常發洩情緒勒索我',
#   'likeCount': 85,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '健行科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'e9d6ae42-b3ae-42d1-9b24-d66919378251',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:12:37.710Z',
#   'updatedAt': '2020-03-31T03:12:37.710Z',
#   'floor': 24,
#   'content': '你真的好棒\n願世人能善待你們的溫柔善良',
#   'likeCount': 60,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '朝陽科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '4adde8af-4abc-498c-8c13-c3d8eab607a7',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:16:22.358Z',
#   'updatedAt': '2020-03-31T03:16:22.358Z',
#   'floor': 25,
#   'content': '校園裡面有你這麼溫暖的人真好🧡\n哥哥不幸中的大幸就是擁有你這個妹妹\n要好好繼續加油哦！',
#   'likeCount': 56,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立臺中科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'c6d9875e-5b8c-4901-8ab5-5a9e140cf1de',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:17:55.970Z',
#   'updatedAt': '2020-03-31T03:17:55.970Z',
#   'floor': 26,
#   'content': '妳也是善良溫暖的人呀☺️',
#   'likeCount': 36,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '長榮大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '7e5f5f1d-b220-41ff-bd37-3757b083a2f3',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:23:27.756Z',
#   'updatedAt': '2020-03-31T03:23:27.756Z',
#   'floor': 27,
#   'content': '辛苦你了！你要了解哥哥並不是你的責任，所以不要讓自己壓力太大！你的善良與愛，世界不會虧待你的🥰🥰😍😍',
#   'likeCount': 46,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '輔仁大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '8c24767b-9dab-4c28-9995-a4c7a8f4943b',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:28:12.458Z',
#   'updatedAt': '2020-03-31T03:28:12.458Z',
#   'floor': 28,
#   'content': '辛苦了！加油！妳很棒！',
#   'likeCount': 9,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立臺中科技大學',
#   'department': '應用英語系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '5903874d-7493-4ff7-b68f-09592c20d0a8',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:35:20.296Z',
#   'updatedAt': '2020-03-31T03:36:30.016Z',
#   'floor': 29,
#   'content': '我們無時無刻不在成長中，\n成長的每個階段，難免會有不同的想法，\n重要的是，後來的我們，成為了什麼樣子。\n\n不必太過在意曾經的想法\n因為現在的你，已經是個願意為人著想，溫暖而善良的人。我們喜歡你現在的樣子。未來會變得怎麼樣，我們不知道，但只要能記住現在的感覺，那就可以了。\n\n請愉快地小步躍著前行吧～',
#   'likeCount': 135,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '麻瓜燉雞',
#   'department': 'feya13',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'c8939fcc-41ec-4988-85d1-6ec150718005',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:40:51.862Z',
#   'updatedAt': '2020-03-31T03:40:51.862Z',
#   'floor': 30,
#   'content': '妹妹 很可以喔',
#   'likeCount': 8,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立高雄科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''}]

# %%
len(resp.json())
# Out:
# 30

# %%
for i in resp.json():
    if "content" in i:
        print(i['content'])
# Out:
# 妳和你哥都辛苦了  加油
# 終於有正常的文章
#
#
# 第一次有這麼多愛心@@
# B130
# 真是一個滿分的妹妹………
# 都辛苦了
# 你是個很好的妹妹
# 別給自己太大的壓力
# 感覺妳已經很棒了
# 辛苦了，你很棒
# 你是一個好妹妹，辛苦你了，要加油唷
# 辛苦妳了，妳哥哥也是
#
# 加油加油努力過好每一天💪💪
# 你很好！是哥哥的天使！更是哥哥的全部
# 我姐也是智能不足
# 辛苦了～
# 辛苦妳了 妳最棒了QQ
# 哥哥一定很謝謝有你這個好妹妹❤️
# 真的你好棒！你也是一個很善良的人喔 跟你哥哥果然是最好的夥伴呢o(≧v≦)o
# 都辛苦了♡你真的很棒！
# 你是個好妹妹
# 文筆好好
# 妳是一個很棒的妹妹
# 也謝謝妳的這篇文章
# 讓人覺得心裡暖洋洋的
# 妳們都是心地善良的小天使
# 加油
# 老闆⋯⋯我的早餐你怎麼加那麼多生洋蔥⋯⋯
# 只是喝杯奶茶怎麼沒味道...
# 啊抱歉我眼淚滴太多了
# 看到標題以為是母湯的
# 我的課本上都是我的淚😭
# （抱
# 好暖心喔！反而是當媽媽的怎麼都會把情緒發洩小孩身上 很舒壓？媽的！因為我也是被媽媽時常發洩情緒勒索我
# 你真的好棒
# 願世人能善待你們的溫柔善良
# 校園裡面有你這麼溫暖的人真好🧡
# 哥哥不幸中的大幸就是擁有你這個妹妹
# 要好好繼續加油哦！
# 妳也是善良溫暖的人呀☺️
# 辛苦你了！你要了解哥哥並不是你的責任，所以不要讓自己壓力太大！你的善良與愛，世界不會虧待你的🥰🥰😍😍
# 辛苦了！加油！妳很棒！
# 我們無時無刻不在成長中，
# 成長的每個階段，難免會有不同的想法，
# 重要的是，後來的我們，成為了什麼樣子。
#
# 不必太過在意曾經的想法
# 因為現在的你，已經是個願意為人著想，溫暖而善良的人。我們喜歡你現在的樣子。未來會變得怎麼樣，我們不知道，但只要能記住現在的感覺，那就可以了。
#
# 請愉快地小步躍著前行吧～
# 妹妹 很可以喔

# %% [markdown]
# ### 查看30樓以後的留言

# %%
floor = 30
url = "https://www.dcard.tw/service/api/v2/posts/233377179/comments?after={}".format(floor)

resp = requests.get(url)
resp.json()
# Out:
# [{'id': 'fa35f5f2-1198-4b9e-b314-ab3577a9ee7e',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:46:56.225Z',
#   'updatedAt': '2020-03-31T03:46:56.225Z',
#   'floor': 31,
#   'content': 'B23 媽媽應該也很痛苦吧？\n光是照顧一個正常的孩子都足以讓父母崩潰了，何況是一個智能不足的小孩，我看過很多那樣的家庭，他們真的很辛苦，不論金錢、外人眼光還是什麼，總有一堆麻煩事等著他們😢😢',
#   'likeCount': 238,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '亞洲大學',
#   'department': '財務金融學系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '5b8005ca-848f-493a-89e5-cb850eaaac3d',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:54:55.281Z',
#   'updatedAt': '2020-03-31T03:54:55.281Z',
#   'floor': 32,
#   'content': '妳很棒',
#   'likeCount': 3,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '靜宜大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '1b31837c-3120-415d-b347-0377fb429dfe',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:59:56.504Z',
#   'updatedAt': '2020-03-31T04:00:20.136Z',
#   'floor': 33,
#   'content': '不知道為什麼 有些內容心境很像陽光普照電影的情節 我也是深入提到家人 情緒就會忍不住潰提',
#   'likeCount': 28,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立中興大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '3d54ba1d-03c8-4787-ab06-52189b0202f2',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:03:50.161Z',
#   'updatedAt': '2020-03-31T04:10:39.393Z',
#   'floor': 34,
#   'content': 'B33 我只是想把陽光讓給了弟弟……',
#   'likeCount': 19,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立虎尾科技大學',
#   'department': '動力機械工程系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '2542583a-818e-4488-8a5f-5ed8947bda31',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:05:04.858Z',
#   'updatedAt': '2020-03-31T04:05:04.858Z',
#   'floor': 35,
#   'content': '看標題以為你被怎麼了⋯',
#   'likeCount': 6,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '中國科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '05b97c9e-0860-418a-866b-334ee82c4817',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:09:17.857Z',
#   'updatedAt': '2020-03-31T04:09:17.857Z',
#   'floor': 36,
#   'content': '看完有種想抱著你說，你辛苦了的衝動。',
#   'likeCount': 8,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '別跟我搶餅乾',
#   'department': 'ghi159762',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '6def9ecc-d141-4161-9d8f-f341c609abcb',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:10:34.615Z',
#   'updatedAt': '2020-03-31T04:10:34.615Z',
#   'floor': 37,
#   'content': '我看到了天使(´⊙ω⊙`)',
#   'likeCount': 9,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立暨南國際大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '02384b93-2822-4927-8937-a09cfa83baba',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:15:52.287Z',
#   'updatedAt': '2020-03-31T04:15:52.287Z',
#   'floor': 38,
#   'content': 'B31 我只能說我長大才知道我媽真的超辛苦\n\n我是一個過動兒(小時候啦\n小時候造成我媽超多麻煩……(我媽是說很少發脾氣也只有我頑皮的上時候',
#   'likeCount': 24,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立虎尾科技大學',
#   'department': '動力機械工程系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'f1ae9458-7c2e-4317-a48a-42179ed12aad',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:16:53.279Z',
#   'updatedAt': '2020-03-31T04:16:53.279Z',
#   'floor': 39,
#   'content': '真暖！好妹妹！！',
#   'likeCount': 3,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立臺灣大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '89a90c44-d69a-4bc9-bd59-113ac578b6ed',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:16:59.549Z',
#   'updatedAt': '2020-03-31T04:17:41.220Z',
#   'floor': 40,
#   'content': '也許不是滿分的妹妹\n但是在你哥哥眼中永遠都會是100分的家人\n哥哥會這樣就是命運\n難過就哭吧\n但還是希望妳能勇敢的陪伴哥哥走完餘生',
#   'likeCount': 68,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立交通大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '322b0f27-78e4-4ab3-a373-dbac46e83ff0',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:27:45.977Z',
#   'updatedAt': '2020-03-31T04:27:45.977Z',
#   'floor': 41,
#   'content': '這文筆好像在看以前國文課本上會出現的文章\n雖然我沒兄弟姊妹，但深刻的描繪看了還是讓我很有感觸很想哭',
#   'likeCount': 48,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '嶺東科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '049108f7-0d20-46f5-a511-b22250275241',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:28:31.334Z',
#   'updatedAt': '2020-03-31T04:28:31.334Z',
#   'floor': 42,
#   'content': 'Do you wanna build a snowman',
#   'likeCount': 34,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立清華大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '0d707505-6608-4d44-be4a-808444e3fc57',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:30:46.600Z',
#   'updatedAt': '2020-03-31T04:30:46.600Z',
#   'floor': 43,
#   'content': '看得好想哭 你真的是個好妹妹',
#   'likeCount': 8,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '世新大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'e77409d3-ef67-43b6-85bc-d5f46d97bbbc',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:32:49.332Z',
#   'updatedAt': '2020-03-31T04:32:49.332Z',
#   'floor': 44,
#   'content': '真的眼眶泛淚🥺🥺\n親情總是最容易觸犯淚腺的地方🥺',
#   'likeCount': 15,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '僑光科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'ac511e24-f222-472a-b83d-11124792d010',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:35:17.338Z',
#   'updatedAt': '2020-03-31T04:35:17.338Z',
#   'floor': 45,
#   'content': '我怎麼覺得你哥的智商比一堆發廢文的高很多',
#   'likeCount': 79,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '逢甲大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '11bc1066-b106-4fb9-8607-979ac26cba63',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:35:30.251Z',
#   'updatedAt': '2020-03-31T04:35:30.251Z',
#   'floor': 46,
#   'content': '你很棒你哥一定很開心有你這樣的妹妹💪',
#   'likeCount': 2,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '僑光科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'caddd3db-ddc9-46eb-8c5b-0dc52803d191',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:36:50.158Z',
#   'updatedAt': '2020-03-31T04:36:50.158Z',
#   'floor': 47,
#   'content': '暖文',
#   'likeCount': 5,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '逢甲大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'e7621187-d72c-4af6-ae54-9c812eeb6f88',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:45:04.631Z',
#   'updatedAt': '2020-03-31T04:45:04.631Z',
#   'floor': 48,
#   'content': '給妳100分\n真的是一個好妹妹\n但自己壓力不要給自己太大\n加油～',
#   'likeCount': 6,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '中華醫事科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '5264cddc-b36f-49fa-a6ec-3f11d7fdf7f4',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:47:42.512Z',
#   'updatedAt': '2020-03-31T04:47:42.512Z',
#   'floor': 49,
#   'content': '他不笨他是我哥哥😭',
#   'likeCount': 33,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '迷路的人',
#   'department': 'mim',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'fa502fe1-d279-4042-bb4a-4279f27a24e9',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:47:51.996Z',
#   'updatedAt': '2020-03-31T04:47:51.996Z',
#   'floor': 50,
#   'content': '哥哥加油！！！！！！',
#   'likeCount': 3,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '修平科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'c6eabeaf-d228-492b-92b9-429cd816211a',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:51:57.511Z',
#   'updatedAt': '2020-03-31T04:51:57.511Z',
#   'floor': 51,
#   'content': '這篇洋蔥也加太多了吧QQ',
#   'likeCount': 8,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '中國文化大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'd9857f57-1eb9-4648-8081-173a7b290773',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:53:41.866Z',
#   'updatedAt': '2020-03-31T04:53:41.866Z',
#   'floor': 52,
#   'content': '看到那句如果受傷的是我就好了...\n\n心酸了一下，你真的很懂事，你是最棒的！！\n\n加油！！',
#   'likeCount': 20,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立高雄科技大學',
#   'department': '電子工程系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '6ffc3228-8e03-42d1-b49d-4264d8ec26ec',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:57:59.669Z',
#   'updatedAt': '2020-03-31T04:57:59.669Z',
#   'floor': 53,
#   'content': '平常不按愛心的 久違的又按了一個\n你們很棒 真的',
#   'likeCount': 5,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '嶺東科技大學',
#   'department': '視覺傳達設計系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '6edd65a0-3f13-49ae-b8ca-c492694103cb',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T05:03:56.495Z',
#   'updatedAt': '2020-03-31T05:03:56.495Z',
#   'floor': 54,
#   'content': '為什麼會哭啦！這篇真的是好文欸👍👍看了感觸好深',
#   'likeCount': 7,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立嘉義大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'fd2ce03d-c66a-4f55-a5b0-d5cd00e5a710',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T05:12:30.616Z',
#   'updatedAt': '2020-03-31T05:12:30.616Z',
#   'floor': 55,
#   'content': '願善良的你們會被世界溫柔相待',
#   'likeCount': 18,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立政治大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '4de777ac-8b0f-4b03-bbed-dbeec1a99329',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T05:20:56.853Z',
#   'updatedAt': '2020-03-31T05:20:56.853Z',
#   'floor': 56,
#   'content': '加油💪🏻',
#   'likeCount': 2,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '大葉大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '68c24b55-8e20-4e70-b6ff-001d11f8056d',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T05:22:06.581Z',
#   'updatedAt': '2020-03-31T05:22:06.581Z',
#   'floor': 57,
#   'content': '願你們兄妹倆一切都好❤️',
#   'likeCount': 7,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '輔仁大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'bd328e45-cff0-4858-aa3c-d36b5cdd820a',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T05:22:11.577Z',
#   'updatedAt': '2020-03-31T05:22:11.577Z',
#   'floor': 58,
#   'content': '覺得好心酸😔\n\n\n不過比起一些微西斯的垃圾廢文\n這才是適合低卡的',
#   'likeCount': 24,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '大仁科技大學',
#   'department': '藥學系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'eabf8d41-e45d-475f-bf4d-267e8f536e07',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T05:23:02.963Z',
#   'updatedAt': '2020-03-31T05:23:02.963Z',
#   'floor': 59,
#   'content': '好哥哥和超級好妹妹',
#   'likeCount': 3,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立中興大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'b6fc8080-ef69-4e9c-9498-144a66a563cd',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T05:24:14.410Z',
#   'updatedAt': '2020-03-31T05:24:14.410Z',
#   'floor': 60,
#   'content': '祝一切安好',
#   'likeCount': 2,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '紫薇不會斗數',
#   'department': 'adobe250258',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''}]

# %% [markdown]
# ### 顯示前n個樓層

# %%
floor = 50
url = "https://www.dcard.tw/service/api/v2/posts/233377179/comments?limit={}".format(floor)

resp = requests.get(url)
resp.json()
# Out:
# [{'id': '1f4c8e1f-a48f-4d9a-8b7f-7f88fda4c847',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T19:53:32.993Z',
#   'updatedAt': '2020-03-30T19:53:32.993Z',
#   'floor': 1,
#   'content': '妳和你哥都辛苦了  加油',
#   'likeCount': 4817,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立雲林科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '7c91dc95-84a6-4679-b04b-cd9d030fd7b6',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T20:15:39.247Z',
#   'updatedAt': '2020-03-31T23:37:02.221Z',
#   'floor': 2,
#   'content': '終於有正常的文章\n\n\n第一次有這麼多愛心@@\nB130',
#   'likeCount': 7165,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立臺灣大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '8a172145-4c36-4859-8c4c-9a0284e658ca',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T20:24:05.504Z',
#   'updatedAt': '2020-03-30T20:24:05.504Z',
#   'floor': 3,
#   'content': '真是一個滿分的妹妹………',
#   'likeCount': 4848,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '中國醫藥大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'cdd73c45-2a6d-443e-9cdc-d8cefca1120e',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T21:30:37.743Z',
#   'updatedAt': '2020-03-30T21:30:37.743Z',
#   'floor': 4,
#   'content': '都辛苦了\n你是個很好的妹妹\n別給自己太大的壓力\n感覺妳已經很棒了',
#   'likeCount': 586,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '鯊魚養殖戶',
#   'department': 'chin_yu',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'a6134ff7-5421-49c8-a0ca-e14a82f899f3',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T21:34:10.255Z',
#   'updatedAt': '2020-03-30T21:34:10.255Z',
#   'floor': 5,
#   'content': '辛苦了，你很棒',
#   'likeCount': 164,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '新北倉鼠系',
#   'department': 'milk_0711',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '45093d81-a1a8-44a4-9cee-56faf333a103',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T23:32:35.230Z',
#   'updatedAt': '2020-03-30T23:32:35.230Z',
#   'floor': 6,
#   'content': '你是一個好妹妹，辛苦你了，要加油唷',
#   'likeCount': 183,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '中國文化大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'b8bd2d94-8643-431d-9b60-3ba0b924f020',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T00:05:07.517Z',
#   'updatedAt': '2020-03-31T00:05:07.517Z',
#   'floor': 7,
#   'withNickname': False,
#   'hiddenByAuthor': True,
#   'meta': {},
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': True,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'b2dcaebe-99ee-4930-aec9-11d5aa2d43b7',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T00:05:34.162Z',
#   'updatedAt': '2020-03-31T00:05:34.162Z',
#   'floor': 8,
#   'content': '辛苦妳了，妳哥哥也是\n\n加油加油努力過好每一天💪💪',
#   'likeCount': 124,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '高苑科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '9980882a-4621-4bf9-9261-b71d2cc1e3f4',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T00:43:26.471Z',
#   'updatedAt': '2020-03-31T00:43:26.471Z',
#   'floor': 9,
#   'content': '你很好！是哥哥的天使！更是哥哥的全部',
#   'likeCount': 235,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '僑光科技大學',
#   'department': 'okevin_d',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'aa00cdef-6fad-4269-839d-29ae439bd2cb',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T01:14:13.510Z',
#   'updatedAt': '2020-03-31T01:14:13.510Z',
#   'floor': 10,
#   'content': '我姐也是智能不足\n辛苦了～',
#   'likeCount': 130,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立交通大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '2595dd43-d933-46fe-8edb-0cf1b780fdf5',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T01:37:55.039Z',
#   'updatedAt': '2020-03-31T01:37:55.039Z',
#   'floor': 11,
#   'content': '辛苦妳了 妳最棒了QQ',
#   'likeCount': 60,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '耕莘健康管理專科學校',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'e94ae3ca-3666-43f6-953d-09be8a83d8fb',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T01:45:55.917Z',
#   'updatedAt': '2020-03-31T01:45:55.917Z',
#   'floor': 12,
#   'content': '哥哥一定很謝謝有你這個好妹妹❤️',
#   'likeCount': 99,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '致理科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'e161efd9-ac2e-4a65-994c-208024f64886',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T01:46:53.437Z',
#   'updatedAt': '2020-03-31T01:46:53.437Z',
#   'floor': 13,
#   'content': '真的你好棒！你也是一個很善良的人喔 跟你哥哥果然是最好的夥伴呢o(≧v≦)o',
#   'likeCount': 109,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '輔英科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '5bf9b416-1d24-4a30-943a-23bf125ecc66',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T02:01:54.018Z',
#   'updatedAt': '2020-03-31T02:01:54.018Z',
#   'floor': 14,
#   'content': '都辛苦了♡你真的很棒！',
#   'likeCount': 48,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立中央大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'b21f10f9-98ef-4fa8-a401-76c1ca07bbc8',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T02:13:22.608Z',
#   'updatedAt': '2020-03-31T02:13:22.608Z',
#   'floor': 15,
#   'content': '你是個好妹妹',
#   'likeCount': 42,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '高雄醫學大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'a33a29fc-c7f0-42b2-b043-5e0be7ead88b',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T02:23:10.263Z',
#   'updatedAt': '2020-03-31T02:23:10.263Z',
#   'floor': 16,
#   'content': '文筆好好\n妳是一個很棒的妹妹\n也謝謝妳的這篇文章\n讓人覺得心裡暖洋洋的\n妳們都是心地善良的小天使',
#   'likeCount': 275,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立政治大學',
#   'department': '法律研究所',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '1953b3a7-e185-481f-a33f-b056b1a1b874',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T02:40:51.653Z',
#   'updatedAt': '2020-03-31T02:40:51.653Z',
#   'floor': 17,
#   'content': '加油',
#   'likeCount': 23,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '臺北城市科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '13a14d36-225b-4b41-8424-599878a1cc53',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T02:52:05.512Z',
#   'updatedAt': '2020-03-31T02:52:05.512Z',
#   'floor': 18,
#   'content': '老闆⋯⋯我的早餐你怎麼加那麼多生洋蔥⋯⋯',
#   'likeCount': 177,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立中正大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '7703069e-527b-4b95-bcaf-87306dbc1d62',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:01:44.512Z',
#   'updatedAt': '2020-03-31T03:01:44.512Z',
#   'floor': 19,
#   'content': '只是喝杯奶茶怎麼沒味道...\n啊抱歉我眼淚滴太多了',
#   'likeCount': 147,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '致理科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '189548ff-c2d1-4bb0-be5c-ccdfaf555c9e',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:02:08.444Z',
#   'updatedAt': '2020-03-31T03:02:08.444Z',
#   'floor': 20,
#   'content': '看到標題以為是母湯的',
#   'likeCount': 113,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '長榮大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'd5002f85-36e8-4623-99c6-f211789260a2',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:07:17.609Z',
#   'updatedAt': '2020-03-31T03:07:17.609Z',
#   'floor': 21,
#   'content': '我的課本上都是我的淚😭',
#   'likeCount': 59,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立臺北商業大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'c36ad4f0-ae74-41d1-8523-092f07177879',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:07:17.884Z',
#   'updatedAt': '2020-03-31T03:07:17.884Z',
#   'floor': 22,
#   'content': '（抱',
#   'likeCount': 20,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '朝陽科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'b2bebbcf-f4c2-4684-9214-565311914b45',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:11:30.775Z',
#   'updatedAt': '2020-03-31T03:11:30.775Z',
#   'floor': 23,
#   'content': '好暖心喔！反而是當媽媽的怎麼都會把情緒發洩小孩身上 很舒壓？媽的！因為我也是被媽媽時常發洩情緒勒索我',
#   'likeCount': 85,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '健行科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'e9d6ae42-b3ae-42d1-9b24-d66919378251',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:12:37.710Z',
#   'updatedAt': '2020-03-31T03:12:37.710Z',
#   'floor': 24,
#   'content': '你真的好棒\n願世人能善待你們的溫柔善良',
#   'likeCount': 60,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '朝陽科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '4adde8af-4abc-498c-8c13-c3d8eab607a7',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:16:22.358Z',
#   'updatedAt': '2020-03-31T03:16:22.358Z',
#   'floor': 25,
#   'content': '校園裡面有你這麼溫暖的人真好🧡\n哥哥不幸中的大幸就是擁有你這個妹妹\n要好好繼續加油哦！',
#   'likeCount': 56,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立臺中科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'c6d9875e-5b8c-4901-8ab5-5a9e140cf1de',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:17:55.970Z',
#   'updatedAt': '2020-03-31T03:17:55.970Z',
#   'floor': 26,
#   'content': '妳也是善良溫暖的人呀☺️',
#   'likeCount': 36,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '長榮大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '7e5f5f1d-b220-41ff-bd37-3757b083a2f3',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:23:27.756Z',
#   'updatedAt': '2020-03-31T03:23:27.756Z',
#   'floor': 27,
#   'content': '辛苦你了！你要了解哥哥並不是你的責任，所以不要讓自己壓力太大！你的善良與愛，世界不會虧待你的🥰🥰😍😍',
#   'likeCount': 46,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '輔仁大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '8c24767b-9dab-4c28-9995-a4c7a8f4943b',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:28:12.458Z',
#   'updatedAt': '2020-03-31T03:28:12.458Z',
#   'floor': 28,
#   'content': '辛苦了！加油！妳很棒！',
#   'likeCount': 9,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立臺中科技大學',
#   'department': '應用英語系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '5903874d-7493-4ff7-b68f-09592c20d0a8',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:35:20.296Z',
#   'updatedAt': '2020-03-31T03:36:30.016Z',
#   'floor': 29,
#   'content': '我們無時無刻不在成長中，\n成長的每個階段，難免會有不同的想法，\n重要的是，後來的我們，成為了什麼樣子。\n\n不必太過在意曾經的想法\n因為現在的你，已經是個願意為人著想，溫暖而善良的人。我們喜歡你現在的樣子。未來會變得怎麼樣，我們不知道，但只要能記住現在的感覺，那就可以了。\n\n請愉快地小步躍著前行吧～',
#   'likeCount': 136,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '麻瓜燉雞',
#   'department': 'feya13',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'c8939fcc-41ec-4988-85d1-6ec150718005',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:40:51.862Z',
#   'updatedAt': '2020-03-31T03:40:51.862Z',
#   'floor': 30,
#   'content': '妹妹 很可以喔',
#   'likeCount': 8,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立高雄科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'fa35f5f2-1198-4b9e-b314-ab3577a9ee7e',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:46:56.225Z',
#   'updatedAt': '2020-03-31T03:46:56.225Z',
#   'floor': 31,
#   'content': 'B23 媽媽應該也很痛苦吧？\n光是照顧一個正常的孩子都足以讓父母崩潰了，何況是一個智能不足的小孩，我看過很多那樣的家庭，他們真的很辛苦，不論金錢、外人眼光還是什麼，總有一堆麻煩事等著他們😢😢',
#   'likeCount': 238,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '亞洲大學',
#   'department': '財務金融學系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '5b8005ca-848f-493a-89e5-cb850eaaac3d',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:54:55.281Z',
#   'updatedAt': '2020-03-31T03:54:55.281Z',
#   'floor': 32,
#   'content': '妳很棒',
#   'likeCount': 3,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '靜宜大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '1b31837c-3120-415d-b347-0377fb429dfe',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:59:56.504Z',
#   'updatedAt': '2020-03-31T04:00:20.136Z',
#   'floor': 33,
#   'content': '不知道為什麼 有些內容心境很像陽光普照電影的情節 我也是深入提到家人 情緒就會忍不住潰提',
#   'likeCount': 28,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立中興大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '3d54ba1d-03c8-4787-ab06-52189b0202f2',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:03:50.161Z',
#   'updatedAt': '2020-03-31T04:10:39.393Z',
#   'floor': 34,
#   'content': 'B33 我只是想把陽光讓給了弟弟……',
#   'likeCount': 19,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立虎尾科技大學',
#   'department': '動力機械工程系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '2542583a-818e-4488-8a5f-5ed8947bda31',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:05:04.858Z',
#   'updatedAt': '2020-03-31T04:05:04.858Z',
#   'floor': 35,
#   'content': '看標題以為你被怎麼了⋯',
#   'likeCount': 6,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '中國科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '05b97c9e-0860-418a-866b-334ee82c4817',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:09:17.857Z',
#   'updatedAt': '2020-03-31T04:09:17.857Z',
#   'floor': 36,
#   'content': '看完有種想抱著你說，你辛苦了的衝動。',
#   'likeCount': 8,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '別跟我搶餅乾',
#   'department': 'ghi159762',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '6def9ecc-d141-4161-9d8f-f341c609abcb',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:10:34.615Z',
#   'updatedAt': '2020-03-31T04:10:34.615Z',
#   'floor': 37,
#   'content': '我看到了天使(´⊙ω⊙`)',
#   'likeCount': 9,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立暨南國際大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '02384b93-2822-4927-8937-a09cfa83baba',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:15:52.287Z',
#   'updatedAt': '2020-03-31T04:15:52.287Z',
#   'floor': 38,
#   'content': 'B31 我只能說我長大才知道我媽真的超辛苦\n\n我是一個過動兒(小時候啦\n小時候造成我媽超多麻煩……(我媽是說很少發脾氣也只有我頑皮的上時候',
#   'likeCount': 24,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立虎尾科技大學',
#   'department': '動力機械工程系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'f1ae9458-7c2e-4317-a48a-42179ed12aad',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:16:53.279Z',
#   'updatedAt': '2020-03-31T04:16:53.279Z',
#   'floor': 39,
#   'content': '真暖！好妹妹！！',
#   'likeCount': 3,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立臺灣大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '89a90c44-d69a-4bc9-bd59-113ac578b6ed',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:16:59.549Z',
#   'updatedAt': '2020-03-31T04:17:41.220Z',
#   'floor': 40,
#   'content': '也許不是滿分的妹妹\n但是在你哥哥眼中永遠都會是100分的家人\n哥哥會這樣就是命運\n難過就哭吧\n但還是希望妳能勇敢的陪伴哥哥走完餘生',
#   'likeCount': 69,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立交通大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '322b0f27-78e4-4ab3-a373-dbac46e83ff0',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:27:45.977Z',
#   'updatedAt': '2020-03-31T04:27:45.977Z',
#   'floor': 41,
#   'content': '這文筆好像在看以前國文課本上會出現的文章\n雖然我沒兄弟姊妹，但深刻的描繪看了還是讓我很有感觸很想哭',
#   'likeCount': 48,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '嶺東科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '049108f7-0d20-46f5-a511-b22250275241',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:28:31.334Z',
#   'updatedAt': '2020-03-31T04:28:31.334Z',
#   'floor': 42,
#   'content': 'Do you wanna build a snowman',
#   'likeCount': 34,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立清華大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '0d707505-6608-4d44-be4a-808444e3fc57',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:30:46.600Z',
#   'updatedAt': '2020-03-31T04:30:46.600Z',
#   'floor': 43,
#   'content': '看得好想哭 你真的是個好妹妹',
#   'likeCount': 8,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '世新大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'e77409d3-ef67-43b6-85bc-d5f46d97bbbc',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:32:49.332Z',
#   'updatedAt': '2020-03-31T04:32:49.332Z',
#   'floor': 44,
#   'content': '真的眼眶泛淚🥺🥺\n親情總是最容易觸犯淚腺的地方🥺',
#   'likeCount': 15,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '僑光科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'ac511e24-f222-472a-b83d-11124792d010',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:35:17.338Z',
#   'updatedAt': '2020-03-31T04:35:17.338Z',
#   'floor': 45,
#   'content': '我怎麼覺得你哥的智商比一堆發廢文的高很多',
#   'likeCount': 79,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '逢甲大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '11bc1066-b106-4fb9-8607-979ac26cba63',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:35:30.251Z',
#   'updatedAt': '2020-03-31T04:35:30.251Z',
#   'floor': 46,
#   'content': '你很棒你哥一定很開心有你這樣的妹妹💪',
#   'likeCount': 2,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '僑光科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'caddd3db-ddc9-46eb-8c5b-0dc52803d191',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:36:50.158Z',
#   'updatedAt': '2020-03-31T04:36:50.158Z',
#   'floor': 47,
#   'content': '暖文',
#   'likeCount': 5,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '逢甲大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'e7621187-d72c-4af6-ae54-9c812eeb6f88',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:45:04.631Z',
#   'updatedAt': '2020-03-31T04:45:04.631Z',
#   'floor': 48,
#   'content': '給妳100分\n真的是一個好妹妹\n但自己壓力不要給自己太大\n加油～',
#   'likeCount': 6,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '中華醫事科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '5264cddc-b36f-49fa-a6ec-3f11d7fdf7f4',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:47:42.512Z',
#   'updatedAt': '2020-03-31T04:47:42.512Z',
#   'floor': 49,
#   'content': '他不笨他是我哥哥😭',
#   'likeCount': 33,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '迷路的人',
#   'department': 'mim',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'fa502fe1-d279-4042-bb4a-4279f27a24e9',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:47:51.996Z',
#   'updatedAt': '2020-03-31T04:47:51.996Z',
#   'floor': 50,
#   'content': '哥哥加油！！！！！！',
#   'likeCount': 3,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '修平科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''}]
