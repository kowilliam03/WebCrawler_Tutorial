# %% [markdown]
# ### 首先先載入相關的套件

# %%
import requests

# %% [markdown]
# ### 透過```requests.get()```的方式，可以直接像目標網站發送請求，網站回傳的結果便會儲存在變數```resp```中。

# %%
url = 'https://www.dcard.tw/f'
header = {'user-agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'}

resp = requests.get(url, headers=header)

# %% [markdown]
# ### 透過status_code來查看回傳的狀態種類。
#
# - ### 1xx: 訊息，代表請求已被接受，需要繼續處理。
#     - 例如：102，伺服器已經收到請求並正在處理。這類型的訊息並不常出現。
# - ### 2xx: 成功，代表請求已成功被伺服器接收、理解、並接受。
#     - 例如：200，請求已成功，請求的內容隨此回應返回。
# - ### 3xx: 重新導向，代表需要用戶端採取進一步的操作才能完成請求。
#     - 例如：305，被請求的資源必須通過指定的代理才能被存取。
# - ### 4xx: 用戶端錯誤，代表了用戶端看起來可能發生了錯誤，妨礙了伺服器的處理。
#     - 例如：404，請求失敗，請求所希望得到的資源未被在伺服器上發現，但允許用戶的後續請求。
# - ### 5xx: 伺服器錯誤，代表服器無法完成明顯有效的請求。
#     - 例如：500，伺服器遇到意外狀況，無法完成請求的處理。

# %%
resp.status_code
# Out:
# 200

# %% [markdown]
# ### 查看抓下來的內容

# %%
resp.text
# Out:
# '<!DOCTYPE html><html lang="zh-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https://schema.org/WebSite"><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1"/><meta name="apple-mobile-web-app-status-bar-style" content="default"/><link rel="stylesheet" type="text/css" href="https://fonts.googleapis.com/css?family=Roboto:400,300"/><meta name="application-name" content="Dcard"/><meta name="apple-itunes-app" content="app-id=951353454"/><meta name="theme-color" content="#006aa6"/><meta name="mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta name="supported-color-schemes" content="light"/><meta property="fb:app_id" content="211628828926493"/><meta property="fb:pages" content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764"/><meta property="al:ios:app_store_id" content="951353454"/><meta property="al:ios:app_name" content="Dcard"/><meta property="al:android:package" content="com.sparkslab.dcardreader"/><meta property="al:android:app_name" content="Dcard"/><link rel="manifest" href="/_next/static/manifest.json"/><link rel="icon" type="image/png" sizes="16x16" href="/_next/static/images/icon-16-1daa7474e5fe761a7239d12c56b88680.png"/><link rel="icon" type="image/png" sizes="24x24" href="/_next/static/images/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png"/><link rel="icon" type="image/png" sizes="32x32" href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><link rel="icon" type="image/png" sizes="192x192" href="/_next/static/images/icon-192-49149beb434e1f6bccac918f6608564c.png"/><link rel="apple-touch-icon" type="image/png" sizes="57x57" href="/_next/static/images/icon-57-c95fcd930b41dbc6de0495348939582f.png"/><link rel="apple-touch-icon" type="image/png" sizes="72x72" href="/_next/static/images/icon-72-69b64cb9aadc811dce34ea6ac772cd8f.png"/><link rel="apple-touch-icon" type="image/png" sizes="76x76" href="/_next/static/images/icon-76-67203a784694f8378d2f51f24970e2f7.png"/><link rel="apple-touch-icon" type="image/png" sizes="114x114" href="/_next/static/images/icon-114-c58f911deb58868e8cc68ea1e09cc688.png"/><link rel="apple-touch-icon" type="image/png" sizes="120x120" href="/_next/static/images/icon-120-f3ada61716c0cc460c2cbe72b18fb9b4.png"/><link rel="apple-touch-icon" type="image/png" sizes="144x144" href="/_next/static/images/icon-144-679d873aa4b58f1117915545d3fdfa1d.png"/><link rel="apple-touch-icon" type="image/png" sizes="152x152" href="/_next/static/images/icon-152-b7ec982f1f49f590c97611e0e5e9f7f3.png"/><link rel="apple-touch-icon" type="image/png" sizes="180x180" href="/_next/static/images/icon-180-2665760e1b88b5af7a3cfbdc532bae20.png"/><link rel="shortcut icon" type="image/png" href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n      new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n      j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n      \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n      })(window,document,\'script\',\'dataLayer\',\'GTM-TWLTW4M\');</script><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><meta name="description" content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"/><meta property="og:description" content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"/><meta property="og:type" content="website"/><meta property="twitter:description" content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"/><meta name="image" itemProp="image" content="https://www.dcard.tw/images/landing.png"/><meta property="og:image" content="https://www.dcard.tw/images/landing.png"/><meta property="og:image:secure_url" content="https://www.dcar ...

# %%
type(resp.text)
# Out:
# str

# %% [markdown]
# ### 從上面可以得知，```requests```已經幫我們把整個網頁抓下來，並存成```str```的格式，但是這種格式不利我們選出想要的資料，這時候就換```BeautifulSoup```上場了：
#
# ### 一樣先載入模組

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# ### lxml是第三方的html解析器(parser)，速度較Python內建的html.parser快，使用前需先下載：
# ```bash
# pip install lxml
# ```

# %%
html = resp.text
soup = BeautifulSoup(html, "lxml")

# %%
# %timeit BeautifulSoup(html, "lxml")
# %timeit BeautifulSoup(html, "html.parser")
# Out:
# 29.5 ms ± 999 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 38.9 ms ± 1.89 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ###  透過```prettify()```將結果排版後輸出

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="zh-TW">
#  <head itemscope="" itemtype="https://schema.org/WebSite" prefix="og: http://ogp.me/ns#">
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/>
#   <meta content="default" name="apple-mobile-web-app-status-bar-style"/>
#   <link href="https://fonts.googleapis.com/css?family=Roboto:400,300" rel="stylesheet" type="text/css"/>
#   <meta content="Dcard" name="application-name"/>
#   <meta content="app-id=951353454" name="apple-itunes-app"/>
#   <meta content="#006aa6" name="theme-color"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="light" name="supported-color-schemes"/>
#   <meta content="211628828926493" property="fb:app_id"/>
#   <meta content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764" property="fb:pages"/>
#   <meta content="951353454" property="al:ios:app_store_id"/>
#   <meta content="Dcard" property="al:ios:app_name"/>
#   <meta content="com.sparkslab.dcardreader" property="al:android:package"/>
#   <meta content="Dcard" property="al:android:app_name"/>
#   <link href="/_next/static/manifest.json" rel="manifest"/>
#   <link href="/_next/static/images/icon-16-1daa7474e5fe761a7239d12c56b88680.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/_next/static/images/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png" rel="icon" sizes="24x24" type="image/png"/>
#   <link href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/_next/static/images/icon-192-49149beb434e1f6bccac918f6608564c.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="/_next/static/images/icon-57-c95fcd930b41dbc6de0495348939582f.png" rel="apple-touch-icon" sizes="57x57" type="image/png"/>
#   <link href="/_next/static/images/icon-72-69b64cb9aadc811dce34ea6ac772cd8f.png" rel="apple-touch-icon" sizes="72x72" type="image/png"/>
#   <link href="/_next/static/images/icon-76-67203a784694f8378d2f51f24970e2f7.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/>
#   <link href="/_next/static/images/icon-114-c58f911deb58868e8cc68ea1e09cc688.png" rel="apple-touch-icon" sizes="114x114" type="image/png"/>
#   <link href="/_next/static/images/icon-120-f3ada61716c0cc460c2cbe72b18fb9b4.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/>
#   <link href="/_next/static/images/icon-144-679d873aa4b58f1117915545d3fdfa1d.png" rel="apple-touch-icon" sizes="144x144" type="image/png"/>
#   <link href="/_next/static/images/icon-152-b7ec982f1f49f590c97611e0e5e9f7f3.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/>
#   <link href="/_next/static/images/icon-180-2665760e1b88b5af7a3cfbdc532bae20.png" rel="apple-touch-icon" sizes="180x180" type="image/png"/>
#   <link href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png" rel="shortcut icon" type="image/png"/>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-TWLTW4M');
#   </script>
#   <meta content="width=device-width" name="viewport"/>
#   <meta charset="utf-8"/>
#   <meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" name="description"/>
#   <meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" property="twitter:description"/>
#   <meta content="https://www.dcard.tw/images/landing.png" itemprop="image" name="image"/>
#   <meta content="https://www.dcard.tw/images/landing.png" property="og:image"/>
#   <meta content="https://www.dcard.tw/images/landing.png" property="og:image:secure_url"/>
#   <meta content="https://www.dcard.tw/images/landing.png" property="twitter:image"/>
#   <title>
#    Dcard
#   </title>
#   <link href="https://www.dcard.tw/f" rel="canonical"/>
#   <meta content="https://www.dcard.tw/f" itemprop="url" name="url"/>
#   <meta content="Dcard" property="og:site_name"/>
#   <meta content="Dcard" property="og:title"/>
#   <meta content="https://www.dcard.tw/f" property="og:url"/>
#   <meta content="Dcard" property="twitter:title"/>
#   <meta content="dcard://category/all/%E5%85%A8%E9%83%A8/hot" property="al:android:url"/>
#   <meta content="dcard://category" property="al:ios:url"/>
#   <script type="application/ld+json">
#    {"@context":"https://schema.org","@type":"CollectionPage","name":"Dcard","url":"https://www.dcard.tw/f","description":"廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"}
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Dcard","item":"https://www.dcard.tw"},{"@type":"ListItem","position":2,"name":"全部","item":"https://www.dcard.tw/f"}]}
#   </script>
#   <meta content="21" name="next-head-count"/>
#   <link as="style" href="/_next/static/css/6d1bbc10820647a103b8.css" rel="preload"/>
#   <link href="/_next/static/css/6d1bbc10820647a103b8.css" rel="stylesheet"/>
#   <link as="script" href="/_next/static/ZJLDskLoICU9r7VrXbrt5/pages/forum.js" rel="preload"/>
#   <link as="script" href="/_next/static/ZJLDskLoICU9r7VrXbrt5/pages/_app.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/commons.45acb83afe343f7bf750.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/36db37cdb824ac796683e509104b86432ac56cc9.db9adb3fe9fc5ee59be2.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/6dad67ea987122f633dbe33c87f65948ae22f8c2.0623b2cd3f14b0f24cc1.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/a2ae04b7a833ed6fd1ce37130abd264ebd97e830.721e3a1b965b2cf4be57.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/146.5ccb13937f1f3b3b6f4d.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/156.64cc388ad91eae549273.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/98.e183d88064080baec759.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/fe8bb93dcba62e8ce8a062d724dbc8a69309bd57.930e22bd9a6baaeeb6d9.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/106.341a75490d857b4cc4e0.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/97.4f02369a917bab6a1b87.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/170.8858b4307afa833f270f.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/22230e2425155829492db097cd516b17f80bb0f3.14e32f33d191dfcf7fb1.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/134.a818cdbf390fbd0075d3.js" rel="preload"/>
#   <link as="script" href="/_next/static/runtime/webpack-7d865a61ea4e63fb5f6e.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/framework.b347b462804689eaf927.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/commons.45acb83afe343f7bf750.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/36db37cdb824ac796683e509104b86432ac56cc9.db9adb3fe9fc5ee59be2.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/60a920ca059d9b881f6db9291d2f6bc362bfb974.20a03db3388401ee95f0.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/6dad67ea987122f633dbe33c87f65948ae22f8c2.0623b2cd3f14b0f24cc1.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/22230e2425155829492db097cd516b17f80bb0f3.14e32f33d191dfcf7fb1.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/4416b39c1b1e4a90c10166cacaa276c0c48fc3c4.01c55215381ba964a2bc.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/69adf62b98132256540c758f2eb6e506cf39b1aa.795f9a2230e82309b291.js" rel="preload"/>
#   <link as="script" href="/_next/static/runtime/main-6aae1a096c1b9125a44d.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/c78d26b1.c961fb3be4c3a9b50951.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/21f1fdb41020907fa53ac8dcc55900f482807900.e11c84f9eeaec5008989.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/37b3cea8be60c06a6ad2432b64f46b6a6963e728.4517cc2dbfc38027fd67.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/f8ff3ace8f4a6bcca4321e0aefe01ad4b0be3ae9.7f5fadc9db091ba90e80.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/ba85f0706285d2608ffb52e0c5a5cb9dd9b6a546.6c8829ea2b05fddd84b8.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/249c150c4efea44fda9ec4fabd3105e5518cc1fe.d830befc0b30c9a96591.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/0fc779a4777b0c6a1e6b8363b1642d83be29aee9.0d1586125a03dedda55c.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/52fc32bf5cf78f153a7a60263a8e279bda882f12.1048ac2c5d46189ee7c5.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/3a5f56208475ad3f306186d53f743ee5fb803ede.2ab3a32f71da0a7d7266.js" rel="preload"/>
#   <style data-styled="gaeSlb bTbYIC dacFof BYkrm kElwiP ktvxUR gEMehv bRgdkb fWeZwO CWnzw goRLrA ktCmNi ctqwNI hboHuu osVsG flgHFG hCDZLD gEBqGb jpXdFc kfXdDt bbbsLJ DkLWL drkUgx cdmmlB jbJUmh homstF eZxyMA bRSgfe iQWJqM jOBGDm rgeaG kxKQHf dSfBfZ cZkFMf SAYuU jeSmua cAhsAU dFYoUA leUIfb kWwnTa iFOhSm dvloGW kcvEyI XuHGb iaoaRA dANmWH hiTmsR gvAvJF btsFiR btyxdF geHAXF blXIQQ ldlYQO iFfAVt hOBRZF bGGVPx fizRcc bFQTAq PiZcj jjwIvU kXvrhl fqtTLp eMXSfJ eFYrsX hRuOXd yLWL cPcxXe eFKNvJ crieHS fHIqqP coCYVj dlyvKU egNafV cBkHYU eeGzXR eQohHX hVmjyp iyEiZp bJEuXb gLHwef faUfSV kukIgj ijHiVA gbDaxp jUDRHq hXEXYl fqicHK drSmAZ jtdKe egoBgt KGljv hlWhQH FSxYW hRbpDK kwWzjf eLVJIY elTwdm eNjcqm cnnesX cGHCFQ krNBKU gkJnjG igiSyv bvalSO hNXlIX lcmPyT cGpUxm XWDjG jRXqQB hKJgyX jKPytA jnFGmH fnUokS fGPsmL RpCDL iwYPTt kFcqPk eTDfPn grnwFb aZFvE gglUe lhzXMC bUZMTr jueEHw gYwJjF bGuAlH HPJWH fDYFAm cYcyMQ ifcbUA kmYity cdwOPp nArqW ejolKO cGIYVA geqEAh eqnpDL dHASZY jpQmJL hxGFYN bYxfmO dKRAFa fBhzEe iIxzGL iYpwSB dBpdSw chpjJz cGDMvT blhVoR jLZYil kaIfrV bKjCHy ezkBZa ezVUnZ ccflTX irzYfI joizCB dPFFvS eyJxfp jfTiSN kGvIbr iJBKht bCffFG irdkmf fIdNgN emkLLu kNUiuk PJors eJVCKv hhGcWV jPDTQd kKpHuw jtGEVN cxftkp kzQRFP fbtLVK kogmmG kWVqST bdkwEy illTCe iyxdng XeqfP cGkAqu cuKSrd cjrmwT dqhhnS eEtwtF eXJZdk dSoULN lbUsFo iGPfkn dbBhGd kzdyix dgBaMi eGHpfO gnrStq fYOPFP cpBbLD dSrvo fuTLmb hrULHr kGNQjf hkmbhH lmkrgH cJzOUb CLUOE gOkApe gykauX fvbcUd ilVlFx ewrJSw tupjO kbhCcZ dKseSj ebSNfi cxZBBR ebAOll jTOxU cNEQPM cjyZdS kNVohA eZsQPM eXbFjv cPWuCq gwveYV hSxPcH cVBveI iVbNfV fQvfed bYLdzW ikqLpQ jeipMt zFRvn hUMQLe gLmFOd dWRRYa iRsvkF irTaNc fkpOlW GnEJV bnCLKC gtLiXJ JInCk kIBWiD kPXEDG mMiGA jmspYp jNJcVh cZEsrV kkIdia kyPfUt brApwE hQqKVz cJzlcl goUrCY kPePTy ghkmQW eNmiGi jpuLiM kHTcQX hNEazt jlApBe fCrYvZ fOXphs dxHwn ldLPex dIaplZ cgnsFz iHfqWy hPKftV iuZiCA gPZLIV NdBvW hZdjnC egSNep rpDwW iDaSAx lpbimL ivyOUa emUyao gxgEFV iUJhUp VoRSe sfCyH deRddy gNeIRi hsZPUX eQqQOc eBbPuw ioHIdq hGKgGu bYftyT jVHMfv gAIWvd efhfxs crcRQC gEjHwc jyllvl gHzERj kAAkSb gfiYPC ewRbYQ bXMydY gcgQSh cFOoEG hHfxHu YiLYW jTBKmc gsRoRt jJHbl fxgWjA iGKvfm jdQXIV eGFfsV eoqJpQ hAxecS eVHTXn iTHuCW fgzMsv kSmyau gMfwEB fbiyFf dQwYDz hzoQLT eUJDwJ bmPvkN dOLhZS cTUUiv ftnTFX gWORFQ yAepW iVpJct xNIDx bPLbwr jUyCFo dNzmDd kWuhLO eWrDFH fYgReK iPmnUl dVjoxE eueuzJ elJwoJ hdPZrL hWWHpO lnyCkY eoBgRD ezgRmy kjmpEs EjNRP dddAwk hmMOjU dRQLtg iqmXir jyDxSd hzndmu hBNlGU cHSadV hVnPOC bjzrBG fRAybs kYhBMN  cQHQtD hTQwm tChPm jhNhvE eHKOot iVGFSe ljAMVO qVUsc glDCsD iWqEkv cjGYlu bAmBXu eRUxcI kAHdPw faLJNL jMIzjs bmrhao eqlEiP jckDJo sSvte fpUWLw kMSWcz dLEnYi bimSFP iyvDRs kAXJWG cnffNM dPORHw dcZxaO ghEcOz gAbqtv atpIK bylGzy hOYKtp hpXCEe jDTSXi wPsvb dJsbwa gzZbZd cIQVEE hENuQg kAYDbe cRymFS iByAXe erjgvQ gaxUPq iNLVWW hyhTOJ jzHSNz ccRXCA laLVYe dBpzwh jpaRaL kRIwhc jdPPuq kVBjNb iuZhTg krHSZP clpdIl iBpnOf ffjPhl dNHhJm fPFxdD hHDFrW gJEPDY guPsiZ gayUeh fTBoxx eYepin ewIODv gEcXhq dfCFGM fMcVje ggsaiW hGzerc jdcDGi klrsvj bseXVK SRiUL llIPbv hucDIL gkunJC ioczgP yFCZq emtuRP iFRmnB hzsFRq lhBbGS hZDMRR iABVNI cKmSxq ewOouQ eSosZd HVhzX cBHgNr gcnrQE jyAVga tHXap ffNsFs cmNIGR iYsdYc ffkUKM fHbojq kOsakL euCzKk dNgTwM UZIgD iwBkJF dfrkYs hpJxoM hhqnRs eOPUIJ dCRYzB SaoMU beExzj fLCZKv flGHCL iJZqpl gVWcXg iuBcDq dQlesi efpsLT InRWB ZprFC bSMFtz hmoclp kAzwXe lhFJk iWeMNp eEKZpa hNibsq kHmVCy kzrWQW jPHUei yPRfd fFyFYv coXckX eLOTme jjtlvm  kirTGc fWNmIM btKhIn iXColI gKgugA bvWIoH eVRwjV ZpfQh fFPjZD fAOwnn jZOVOY fcFtzX hnhJmK apoP bWOeJC fkxjjp bfnwry kePTyJ hbfDmi khJgVN hsNsSw eHdyTY iuZeoZ hFgdiF hehPkh kelVUz hhHEcO gWpGTQ dYMQte ldEhSl jQJhRL iPJGGt khziHD GCORq bTzXjX eDFFbM kNFDXI RMwUL MVWtb kWKjIv fPopSO fOycdi jKEsOX cwtlmZ hBlQch gDAchB fpZiSA jZmKEp hMosuF clYGOR konPyC jokMEq kGuyvC iFnMyW jYClOo bNTlZJ OTrDO kmooua kDoCkm kCjIAT betfUP lctPdT RsHTV jQzNOm hDQjrD CJki bOsSnW jALaGx hzPMCw bbLXty ksJOCl hxhmwZ cVhebS kVGlBf kCfUJx lgwBxr bb ...
#    /* sc-component-id: sc-global-1522344194 */
# body{background-color:#00324e;}
# /* sc-component-id: sc-1rm1ozc-0 */
# .hCDZLD{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .hCDZLD img,.hCDZLD svg{height:100%;width:100%;}.gEBqGb{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:26px;height:26px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .gEBqGb img,.gEBqGb svg{height:100%;width:100%;}.jpXdFc{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:24px;height:24px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .jpXdFc img,.jpXdFc svg{height:100%;width:100%;}.kfXdDt{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:40px;height:40px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .kfXdDt img,.kfXdDt svg{height:100%;width:100%;}.bbbsLJ{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:24px;height:24px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .bbbsLJ img,.bbbsLJ svg{height:100%;width:100%;}.DkLWL{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:28px;height:28px;fill:#c4c4c4;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .DkLWL img,.DkLWL svg{height:100%;width:100%;}.drkUgx{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .drkUgx img,.drkUgx svg{height:100%;width:100%;}.cdmmlB{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:16px;height:16px;fill:rgba(0,0,0,.6);stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .cdmmlB img,.cdmmlB svg{height:100%;width:100%;}.jbJUmh{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:45px;height:45px;fill:rgb(233,233,233);stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .jbJUmh img,.jbJUmh svg{height:100%;width:100%;}.homstF{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:44px;height:44px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .homstF img,.homstF svg{height:100%;width:100%;}.eZxyMA{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:16px;height:16px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .eZxyMA img,.eZxyMA svg{height:100%;width:100%;}.bRSgfe{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:21px;height:21px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(. ...
# /* sc-component-id: ih5c0o-0 */
# .ktCmNi{display:block;-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: ih5c0o-2 */
# .ctqwNI{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;min-width:130px;max-width:640px;height:100%;width:100%;}
# /* sc-component-id: ih5c0o-4 */
# .hboHuu{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;box-sizing:border-box;height:40px;padding:10px 13px;outline:none;border:1px solid #d9d9d9;font-size:16px;line-height:normal;cursor:text;-webkit-flex:1;-ms-flex:1;flex:1;border-radius:10px;color:rgba(0,0,0,.85);} .hboHuu::-webkit-input-placeholder{color:rgba(0,0,0,0.35);} .hboHuu::-moz-placeholder{color:rgba(0,0,0,0.35);} .hboHuu:-ms-input-placeholder{color:rgba(0,0,0,0.35);} .hboHuu::placeholder{color:rgba(0,0,0,0.35);}
# /* sc-component-id: sc-1ehu1w3-0 */
# .bRgdkb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;} .bRgdkb form{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:#00588a;border-radius:4px;overflow:hidden;width:100%;}.fWeZwO{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;} .fWeZwO form{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:#fff;border-radius:6px;overflow:hidden;width:100%;border:solid 1px #d9d9d9;}
# /* sc-component-id: sc-1ehu1w3-1 */
# .CWnzw{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;padding:0 10px;font-size:14px;color:#fff;} .CWnzw::-webkit-search-cancel-button{position:relative;right:-4px;-webkit-appearance:none;-moz-appearance:none;appearance:none;background-image:url('/images/search/close-desktop.svg');background-repeat:none;background-position:center;background-size:cover;height:14px;width:14px;} .CWnzw::-webkit-input-placeholder{color:rgba(255,255,255,0.75);} .CWnzw::-moz-placeholder{color:rgba(255,255,255,0.75);} .CWnzw:-ms-input-placeholder{color:rgba(255,255,255,0.75);} .CWnzw::placeholder{color:rgba(255,255,255,0.75);}.goRLrA{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;padding:0 6px;font-size:16px;} .goRLrA{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;padding:0 6px;font-size:16px;} .goRLrA{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;padding:0 6px;font-size:16px;} .goRLrA{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;padding:0 6px;font-size:16px;} .goRLrA::-webkit-search-cancel-button{position:relative;right:-4px;-webkit-appearance:none;-moz-appearance:none;appearance:none;background-image:url('/images/search/close-mobile.svg');background-repeat:none;background-position:center;background-size:cover;height:18px;width:18px;}
# /* sc-component-id: sc-1ehu1w3-2 */
# .osVsG{background:#006aa6;border:1px solid #00588a;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:0 4px 4px 0;padding:0 9px;cursor:pointer;outline:none;}
# /* sc-component-id: sc-1ehu1w3-3 */
# .gkunJC{padding-left:6px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-1ehu1w3-4 */
# .yFCZq{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding-left:12px;color:rgba(0,0,0,0.5);font-size:16px;font-weight:500;width:50px;}
# /* sc-component-id: sc-1ehu1w3-5 */
# .ioczgP{padding:0 2px;}
# /* sc-component-id: sc-17b0qgb-0 */
# .bseXVK{position:-webkit-sticky;position:sticky;top:0;background:#fff;border-bottom:1px solid #dedede;padding:0 16px;z-index:10;}.SRiUL{position:-webkit-sticky;position:sticky;top:0;background:#fff;border-bottom:1px solid #dedede;padding:0 60px;z-index:10;}
# /* sc-component-id: sc-17b0qgb-1 */
# .llIPbv{padding:8px 0;}
# /* sc-component-id: sc-17b0qgb-2 */
# .hucDIL{height:28px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: sc-17b0qgb-3 */
# .emtuRP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: sc-17b0qgb-4 */
# .iFRmnB{height:100%;white-space:nowrap;-webkit-flex:1;-ms-flex:1;flex:1;} .iFRmnB:first-child{padding-left:0;} .iFRmnB a{color:#000;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:12px 0px;} .iFRmnB a::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}.hzsFRq{height:100%;white-space:nowrap;-webkit-flex:1;-ms-flex:1;flex:1;} .hzsFRq:first-child{padding-left:0;} .hzsFRq a{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:12px 0px;} .hzsFRq a::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}.lhBbGS{height:100%;white-space:nowrap;} .lhBbGS:first-child{padding-left:0;} .lhBbGS a{color:#000;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 20px;} .lhBbGS a::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}.hZDMRR{height:100%;white-space:nowrap;} .hZDMRR:first-child{padding-left:0;} .hZDMRR a{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 20px;} .hZDMRR a::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}
# /* sc-component-id: sc-1erz7nj-0 */
# .ilVlFx{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:10px;font-size:16px;padding:0 16px;height:44px;pointer-events:all;border:none;font-weight:500;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);background:#3397cf;color:rgba(255,255,255,1);width:100%;display:block;} .ilVlFx:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .ilVlFx:hover{background:#006aa6;}.ewrJSw{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:10px;font-size:16px;padding:0 16px;height:44px;pointer-events:all;border:none;font-weight:500;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);background:#3397cf;color:rgba(255,255,255,1);} .ewrJSw:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .ewrJSw:hover{background:#006aa6;}.tupjO{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:8px;font-size:14px;padding:0 14px;height:36px;pointer-events:all;border:none;font-weight:500;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);background:#3397cf;color:rgba(255,255,255,1);} .tupjO:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);}.kbhCcZ{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:10px;font-size:16px;padding:0 16px;height:44px;pointer-events:all;border:none;font-weight:500;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);background:#3397cf;color:rgba(255,255,255,1);} .kbhCcZ:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);}.dKseSj{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:10px;font-size:16px;padding:0 16px;height:44px;pointer-events:all;border:none;font-weight:500;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);background:transparent;color:#3397cf;padding:0 8px;} .dKseSj:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .dKseSj:active{box-shadow:none;} .dKseSj:hover{color:#006aa6;}.ebSNfi{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:10px;font-size:16px;padding:0 16px;height:44px;pointer-events:none;border:none;font-weight:500;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);background:#3397cf;color:rgba(255,255,255,1);background-color:#dfdfdf;color:rgba(255,255,255,1);} .ebSNfi:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .ebSNfi:hover{background:#006aa6;}.cxZBBR{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:10px;font-size:16px;padding:0 16px;height:44px;pointer-events:all;border:none;font-weight:500;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);background:rgba(0,16,32,0.06);color:rgba(0,0,0,0.75);} .cxZ ...
# /* sc-component-id: sc-1erz7nj-2 */
# .bNTlZJ> button{border-radius:0;} .bNTlZJ>*:first-child{border-radius:10px 0 0 10px;border-right-width:0;} .bNTlZJ>*:first-child button{border-radius:10px 0 0 10px;border-right-width:0;} .bNTlZJ>*:last-child{border-radius:0 10px 10px 0;border-left-width:0;} .bNTlZJ>*:last-child button{border-radius:0 10px 10px 0;border-left-width:0;}
# /* sc-component-id: dks15x-0 */
# .fWNmIM{position:relative;}
# /* sc-component-id: dks15x-1 */
# .khJgVN{visibility:hidden;padding-top:calc(100% / 1.5151515151515151);pointer-events:none;}.hsNsSw{visibility:hidden;padding-top:calc(100% / 5);pointer-events:none;}.eHdyTY{visibility:hidden;padding-top:calc(100% / 1);pointer-events:none;}
# /* sc-component-id: dks15x-2 */
# .btKhIn{position:absolute;left:0;top:0;right:0;bottom:0;}
# /* sc-component-id: sc-7580fg-0 */
# .hWekac{width:100%;}
# /* sc-component-id: sc-86hs1l-0 */
# .iwYPTt{height:32px;font-weight:500;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:rgba(0,0,0,0.75);font-size:14px;border-radius:16px;background:#efefef;padding:0 16px;white-space:nowrap;}.kFcqPk{height:32px;font-weight:500;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:rgba(0,0,0,0.75);font-size:13px;border-radius:16px;background:#efefef;padding:0 16px;white-space:nowrap;}
# /* sc-component-id: d14s4-0 */
# .kWuhLO{overflow-y:hidden;}
# /* sc-component-id: d14s4-1 */
# .eWrDFH{overflow-x:auto;overflow-y:hidden;}
# /* sc-component-id: d14s4-2 */
# .fYgReK{white-space:nowrap;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:64px;padding:0 0px;} .fYgReK::after{content:'';-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;height:64px;width:0px;}
# /* sc-component-id: d14s4-3 */
# .jnFGmH{display:block;}
# /* sc-component-id: d14s4-4 */
# .fnUokS{display:inline-block;padding-right:8px;padding-top:8px;} .fnUokS:last-child{padding-right:0;}.fGPsmL{display:inline-block;padding-right:16px;padding-top:16px;} .fGPsmL:last-child{padding-right:0;}.RpCDL{display:inline-block;padding-right:16px;padding-top:px;} .RpCDL:last-child{padding-right:0;}
# /* sc-component-id: sc-1wz6w4a-0 */
# .XWDjG{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:60vh;}.jRXqQB{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:vh;}
# /* sc-component-id: sc-1hi1x4o-0 */
# .kWVqST{margin:10px 0;}
# /* sc-component-id: sc-4ihej7-0 */
# .cGpUxm{white-space:pre-wrap;}
# /* sc-component-id: sc-6yh43a-0 */
# .hNXlIX{font-size:18px;line-height:1.6;word-wrap:break-word;}.lcmPyT{font-size:15px;color:rgba(0,0,0,.6);line-height:1.6;word-wrap:break-word;}
# /* sc-component-id: fsyoh-0 */
# .eNjcqm{font-size:30px;line-height:1.5;font-weight:500;word-wrap:break-word;color:rgba(0,0,0,.95);}.cnnesX{font-size:19px;line-height:1.5;font-weight:500;word-wrap:break-word;color:rgba(0,0,0,.95);}
# /* sc-component-id: sc-405p19-0 */
# .FSxYW{background:#fff;padding:0 60px 0;}.hRbpDK{background:#fff;padding:0 16px 0;}
# /* sc-component-id: sc-405p19-1 */
# .kwWzjf{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-bottom:0px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.eLVJIY{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-bottom:5px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-405p19-2 */
# .elTwdm{-webkit-flex:1;-ms-flex:1;flex:1;overflow:hidden;}
# /* sc-component-id: sc-405p19-3 */
# .cGHCFQ{font-size:14px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-top:12px;}.krNBKU{font-size:13px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-top:12px;}
# /* sc-component-id: sc-405p19-4 */
# .gkJnjG{color:rgba(0,0,0,.35);white-space:nowrap;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;} .gkJnjG:not(:last-child)::after{content:'·';padding:0 0.5em;}
# /* sc-component-id: sc-405p19-5 */
# .igiSyv{padding:22px 0 40px;}.bvalSO{padding:16px 0 24px;}
# /* sc-component-id: sc-405p19-6 */
# .hKJgyX{padding-bottom:16px;}.jKPytA{padding-bottom:24px;}
# /* sc-component-id: sc-1heqsqc-0 */
# .jtdKe{border-radius:50%;overflow:hidden;}
# /* sc-component-id: sc-1heqsqc-1 */
# .ezVUnZ{background:#2490bf;color:#fff;font-size:25.6px;height:40px;width:40px;line-height:40px;text-align:center;border-radius:50%;}.ccflTX{background:#cb3a6b;color:#fff;font-size:25.6px;height:40px;width:40px;line-height:40px;text-align:center;border-radius:50%;}.irzYfI{background:#cb3a6b;color:#fff;font-size:12.8px;height:20px;width:20px;line-height:20px;text-align:center;border-radius:50%;}.joizCB{background:#2490bf;color:#fff;font-size:12.8px;height:20px;width:20px;line-height:20px;text-align:center;border-radius:50%;}.dPFFvS{background:#cb3a6b;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}.eyJxfp{background:#2490bf;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}.jfTiSN{background:#cb3a6b;color:#fff;font-size:64px;height:100px;width:100px;line-height:100px;text-align:center;border-radius:50%;}.kGvIbr{background:#2490bf;color:#fff;font-size:64px;height:100px;width:100px;line-height:100px;text-align:center;border-radius:50%;}.iJBKht{background:#cb3a6b;color:#fff;font-size:20.48px;height:32px;width:32px;line-height:32px;text-align:center;border-radius:50%;}.bCffFG{background:#2490bf;color:#fff;font-size:20.48px;height:32px;width:32px;line-height:32px;text-align:center;border-radius:50%;}
# /* sc-component-id: sc-1heqsqc-2 */
# .ilqlpH{display:block;border-radius:50%;object-fit:cover;}
# /* sc-component-id: vt1ivp-0 */
# .eJVCKv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-left:12px;}
# /* sc-component-id: vt1ivp-1 */
# .hhGcWV{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:rgba(0,0,0,.35);font-size:14px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;} .hhGcWV:hover > *{fill:#ea5c5c;}.jPDTQd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:rgba(0,0,0,.35);font-size:13px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}
# /* sc-component-id: vt1ivp-2 */
# .kKpHuw{cursor:pointer;display:block;margin-right:14px;}.jtGEVN{cursor:pointer;display:block;margin-right:8px;}
# /* sc-component-id: vt1ivp-3 */
# .kRIwhc{background:rgba(0,0,0,0.05);width:1px;height:16px;margin:0 2px 0 10px;}.jdPPuq{background:rgba(0,0,0,0.05);width:1px;height:24px;margin:0 8px 0 16px;}
# /* sc-component-id: sc-1wrppqn-0 */
# .kaIfrV{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:16px;}.bKjCHy{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:13px;}
# /* sc-component-id: sc-1wrppqn-1 */
# .ezkBZa{padding-right:15px;}
# /* sc-component-id: sc-1wrppqn-2 */
# .irdkmf{-webkit-flex:1;-ms-flex:1;flex:1;overflow:hidden;}
# /* sc-component-id: sc-1wrppqn-3 */
# .fIdNgN{color:rgba(0,0,0,.85);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: sc-1wrppqn-4 */
# .emkLLu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;color:rgba(0,0,0,.35);padding-top:3px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: sc-1wrppqn-5 */
# .PJors{color:rgba(0,0,0,.35);}
# /* sc-component-id: sc-1wrppqn-6 */
# .kNUiuk{margin:0 0.5em;border-right:1px solid #dfdfdf;}
# /* sc-component-id: sc-1t5l7uc-0 */
# .chpjJz{color:rgba(0,0,0,.85);font-size:18px;padding:16px 0;border-bottom:1px solid rgb(233,233,233);position:relative;}.cGDMvT{color:rgba(0,0,0,.85);font-size:18px;padding:16px 0;border-bottom:1px solid transparent;position:relative;}.blhVoR{color:rgba(0,0,0,.85);font-size:18px;padding:26px 30px;border-bottom:1px solid transparent;position:relative;}.jLZYil{color:rgba(0,0,0,.85);font-size:18px;padding:26px 20px;border-bottom:1px solid transparent;position:relative;}
# /* sc-component-id: sc-1t5l7uc-1 */
# .iuZiCA{margin-top:20px;padding:10px 0;border-top:1px solid rgb(233,233,233);border-bottom:1px solid rgb(233,233,233);}
# /* sc-component-id: sc-1t5l7uc-2 */
# .gPZLIV{font-size:16px;line-height:30px;color:rgba(0,0,0,.35);margin-bottom:3px;}.NdBvW{font-size:13px;line-height:30px;color:rgba(0,0,0,.35);margin-bottom:3px;}
# /* sc-component-id: sc-1t5l7uc-3 */
# .cxftkp{color:rgba(0,0,0,.85);font-size:18px;line-height:1.6;padding-top:24px;word-break:break-all;} .cxftkp .sc-1g05ju-0 > img{height:25vh;}.kzQRFP{color:rgba(0,0,0,.85);font-size:18px;line-height:1.6;padding-top:24px;word-break:break-all;} .kzQRFP .sc-1g05ju-0 > img{height:initial;}.fbtLVK{color:rgba(0,0,0,.6);font-size:15px;line-height:1.6;padding-top:16px;word-break:break-all;} .fbtLVK .sc-1g05ju-0 > img{height:25vh;}.kogmmG{color:rgba(0,0,0,.6);font-size:15px;line-height:1.6;padding-top:16px;word-break:break-all;} .kogmmG .sc-1g05ju-0 > img{height:initial;}
# /* sc-component-id: sc-1jf3ag7-0 */
# .bYxfmO{padding:0 60px;}.dKRAFa{padding:0 16px;}
# /* sc-component-id: sc-1jf3ag7-1 */
# .fBhzEe{border-bottom:1px solid rgb(233,233,233);padding:2px 0;color:rgba(0,0,0,.35);font-size:16px;font-weight:400;}.iIxzGL{border-bottom:1px solid rgba(0,0,0,0.05);padding:12px 0;color:rgba(0,0,0,.35);font-size:13px;font-weight:400;}
# /* sc-component-id: nxot29-0 */
# .iYpwSB{padding:0 60px;}.dBpdSw{padding:0 16px;}
# /* sc-component-id: nxot29-1 */
# .emUyao{background:#fff;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;border-bottom:1px solid rgb(233,233,233);}.gxgEFV{background:#fff;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:16px 0;border-bottom:1px solid rgb(233,233,233);}
# /* sc-component-id: ku7hkd-0 */
# .cjrmwT{background:#f5f5f5;padding:0 60px;padding-bottom:120px;}
# /* sc-component-id: ku7hkd-1 */
# .dqhhnS{border-top:1px solid rgb(233,233,233);padding:24px 0;}.eEtwtF{border-top:1px solid transparent;padding:24px 0;}
# /* sc-component-id: ku7hkd-2 */
# .eXJZdk{background:#fff;color:rgba(0,0,0,.35);border-radius:4px;border:1px solid rgb(233,233,233);line-height:60px;font-size:18px;padding-left:17px;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;cursor:text;}
# /* sc-component-id: sc-8n4pv8-0 */
# .fOXphs{position:relative;height:120px;padding:16px 0;width:100%;}.dxHwn{position:relative;height:64px;padding:13px 0;width:100%;}
# /* sc-component-id: olnp72-0 */
# .dddAwk{background:#edad1d;color:#fff;padding:14px 0;font-size:14px;text-align:center;}.hmMOjU{background:#EA5C5C;color:#fff;padding:14px 0;font-size:14px;text-align:center;}
# /* sc-component-id: olnp72-1 */
# .gbDaxp{padding:22px 60px;}.jUDRHq{padding:16px 16px;}
# /* sc-component-id: olnp72-2 */
# .hXEXYl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: olnp72-3 */
# .fqicHK{padding-right:15px;}
# /* sc-component-id: olnp72-5 */
# .egoBgt{-webkit-flex:1;-ms-flex:1;flex:1;overflow:hidden;}
# /* sc-component-id: olnp72-6 */
# .KGljv{font-size:16px;color:rgba(0,0,0,.85);white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}.hlWhQH{font-size:13px;color:rgba(0,0,0,.85);white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: olnp72-9 */
# .dRQLtg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-top:22px;}
# /* sc-component-id: olnp72-10 */
# .iqmXir{background:#edad1d;color:#fff;font-size:18px;padding:4px 7px;border-radius:4px;}.jyDxSd{background:#a3a3a3;color:#fff;font-size:15px;padding:4px 7px;border-radius:4px;}.hzndmu{background:#EA5C5C;color:#fff;font-size:18px;padding:4px 7px;border-radius:4px;}.hBNlGU{background:#edad1d;color:#fff;font-size:15px;padding:4px 7px;border-radius:4px;}.cHSadV{background:#EA5C5C;color:#fff;font-size:15px;padding:4px 7px;border-radius:4px;}.hVnPOC{background:#a3a3a3;color:#fff;font-size:18px;padding:4px 7px;border-radius:4px;}
# /* sc-component-id: sc-1kuvyve-0 */
# .HPJWH{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;}.fDYFAm{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;pointer-events:none;}
# /* sc-component-id: sc-1kuvyve-1 */
# .cYcyMQ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.ifcbUA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;opacity:0.75;}
# /* sc-component-id: sc-1kuvyve-2 */
# .kmYity{display:block;height:24px;width:24px;border-radius:50%;border:2px solid #fff;margin-left:-4px;} .kmYity:first-child{margin-left:0;}.cdwOPp{display:block;height:20px;width:20px;border-radius:50%;border:2px solid #fff;margin-left:-4px;} .cdwOPp:first-child{margin-left:0;}.nArqW{display:block;height:21px;width:21px;border-radius:50%;border:2px solid #fff;margin-left:-4px;} .nArqW:first-child{margin-left:0;}
# /* sc-component-id: sc-1kuvyve-3 */
# .ejolKO{padding-left:6px;}
# /* sc-component-id: sc-13t0dac-0 */
# .aZFvE{padding:0 60px;background:#fff;}.gglUe{padding:0 16px;background:#fff;}
# /* sc-component-id: sc-13t0dac-1 */
# .lhzXMC{padding:6px 0;color:rgba(0,0,0,.35);font-size:14px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.bUZMTr{padding:12px 0;color:rgba(0,0,0,.35);font-size:13px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-top:1px solid rgba(0,0,0,0.05);border-bottom:1px solid rgba(0,0,0,0.05);}
# /* sc-component-id: sc-13t0dac-2 */
# .jueEHw{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-13t0dac-3 */
# .cGIYVA{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}
# /* sc-component-id: sc-13t0dac-4 */
# .gYwJjF span{border-color:#fff;}
# /* sc-component-id: sc-1qqve8m-0 */
# .bdkwEy{color:rgba(0,0,0,.35);padding:40px 0;}.illTCe{color:rgba(0,0,0,.35);}
# /* sc-component-id: sc-1qqve8m-1 */
# .iyxdng{display:grid;grid-template-columns:repeat(2,1fr);grid-gap:0 8px;margin-top:10px;padding:0 60px;}.XeqfP{display:grid;grid-template-columns:repeat(1,1fr);grid-gap:0 8px;margin-top:0px;padding:0 16px;}
# /* sc-component-id: sc-1qqve8m-2 */
# .cGkAqu{position:relative;min-width:0;} .cGkAqu:last-child{border-bottom:none;} .cGkAqu a{color:rgba(0,0,0,.85);font-size:16px;font-weight:bold;display:block;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;padding:8px 0 8px 18px;} .cGkAqu a:hover{color:#797979;} .cGkAqu a::before{content:'';width:7px;height:7px;position:absolute;top:0;left:0;bottom:0;border-radius:50%;margin:auto;background:#3397cf;}.cuKSrd{position:relative;min-width:0;border-bottom:1px solid rgba(0,0,0,0.05);} .cuKSrd:last-child{border-bottom:none;} .cuKSrd a{color:rgba(0,0,0,.85);font-size:15px;display:block;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;padding:16px 0 16px 23px;} .cuKSrd a:hover{color:#797979;} .cuKSrd a::before{content:'';width:7px;height:7px;position:absolute;top:0;left:0;bottom:0;border-radius:50%;margin:auto;background:#3397cf;}
# /* sc-component-id: nruxq1-0 */
# .eTDfPn{position:relative;}
# /* sc-component-id: nruxq1-1 */
# .grnwFb{position:absolute;top:50%;left:50%;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);height:300vh;visibility:hidden;pointer-events:none;}
# /* sc-component-id: wve5t5-0 */
# .hVmjyp{border-radius:4px;min-height:100%;width:100%;}.iyEiZp{border-radius:4px;min-height:100%;width:100%;padding:8px 0;}
# /* sc-component-id: wve5t5-1 */
# .bJEuXb{padding:0px 0 0px;margin-top:0px;}.gLHwef{padding:16px 0 16px;margin-top:0px;}.faUfSV{padding:0px 0 0px;margin-top:0px;background:#fff;} .faUfSV:before{display:block;background:rgba(0,0,0,0.05);content:'';height:1px;width:calc(100% - 32px);margin:0 16px;}.kukIgj{padding:0px 0 0px;margin-top:8px;background:#fff;}.ijHiVA{padding:0px 0 0px;margin-top:0px;background:#fff;}
# /* sc-component-id: wve5t5-2 */
# .jpQmJL{padding:60px 0 36px;margin-top:0px;background:#f5f5f5;}.hxGFYN{padding:0px 0 0px;margin-top:8px;background:#fff;background:#fff;}
# /* sc-component-id: wve5t5-3 */
# .geqEAh{background:#fff;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}.eqnpDL{background:#fff;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:16px 0;}
# /* sc-component-id: wve5t5-4 */
# .dSoULN{padding-bottom:px;}.lbUsFo{padding-bottom:50px;}
# /* sc-component-id: wve5t5-5 */
# .kZVGHl{padding:22px 16px;}
# /* sc-component-id: wve5t5-6 */
# .jpaRaL{padding-bottom:120px;}
# /* sc-component-id: sc-1frbu9m-0 */
# .gAIWvd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;text-align:center;padding:50px 0;}
# /* sc-component-id: sc-1frbu9m-1 */
# .efhfxs{display:block;width:250px;margin-bottom:30px;}
# ...
#                  </span>
#                 </div>
#                 <div class="sc-1kuvyve-3 ejolKO">
#                  732
#                 </div>
#                </div>
#               </div>
#               <div class="sc-1v1d5rx-8 eNmiGi">
#                <span class="sc-1v1d5rx-9 jpuLiM">
#                 回應
#                </span>
#                <span>
#                 47
#                </span>
#               </div>
#               <div class="sc-1v1d5rx-8 eNmiGi">
#                <span class="sc-1rm1ozc-0 drkUgx sc-1v1d5rx-10 kHTcQX" role="img" size="20">
#                 <svg viewbox="0 0 24 24">
#                  <path d="M17.65 21.39L12 17.5l-5.65 3.88A1.5 1.5 0 014 20.15V5a2.5 2.5 0 012.5-2.5h11A2.5 2.5 0 0120 5v15.15a1.5 1.5 0 01-2.35 1.24z">
#                  </path>
#                 </svg>
#                </span>
#                <span>
#                 收藏
#                </span>
#               </div>
#              </div>
#              <img alt="" class="t5f2fb-0 kSmyau sc-1v1d5rx-12 hNEazt" height="84px" loading="lazy" src="https://megapx-assets.dcard.tw/images/25a7aa89-4f5a-4030-b546-8fa7846d3cb9/160.jpeg" width="84px"/>
#             </article>
#            </div>
#            <div data-index="37">
#             <article class="sc-1v1d5rx-0 gtLiXJ" data-list-engagement-hot-all="38" data-post-list-viewed-cell-no="38" role="article">
#              <div class="sc-1v1d5rx-2 kIBWiD">
#               <div class="sc-6oxm01-0 kPXEDG">
#                <div class="sc-6oxm01-3 jmspYp">
#                 <span aria-label="女" class="sc-1rm1ozc-0 drkUgx sc-1heqsqc-0 jtdKe" role="img" size="20">
#                  <svg viewbox="0 0 40 40">
#                   <path d="M40 20a20 20 0 11-40 0 20 20 0 0140 0" fill="#F48FB1">
#                   </path>
#                   <path d="M28.7 17.5a9.6 9.6 0 00-1.4-4.4l.9-.6S25.5 6 17.9 7.3c-5.5 1-7.7 5.4-7.4 9C10.8 19.8 8.3 31 8.3 31l6.7 1.7a4.6 4.6 0 00-.7 1.1v.1a4.2 4.2 0 00-.4.8l-1.3 3.8a20 20 0 0010.6 1.1L23 37c.4-2-.4-4-2-5 0-1.1 0-3 .5-3.1 3-.6 5.1-2.5 6.2-5.3.3.2.6.2 1 .2a1.5 1.5 0 00-.2-3c.1-1 .2-2.2 0-3.3z" fill="#CB3A6B">
#                   </path>
#                  </svg>
#                 </span>
#                </div>
#                <div class="sc-6oxm01-1 cZEsrV">
#                 <span class="sc-6oxm01-2 kkIdia">
#                  美妝
#                 </span>
#                 <span class="sc-6oxm01-2 kkIdia">
#                  長庚科技大學
#                 </span>
#                 <span class="sc-6oxm01-2 kkIdia">
#                  4月6日 13:15
#                 </span>
#                </div>
#                <div class="sc-6oxm01-7 kyPfUt">
#                </div>
#               </div>
#              </div>
#              <div class="sc-1v1d5rx-1 brApwE">
#               <h2 class="sc-1v1d5rx-3 hQqKVz">
#                <a class="sc-1v1d5rx-4 cJzlcl" href="/f/makeup/p/233417281">
#                 <span>
#                  台北清粉刺 #內含20年粉刺圖
#                 </span>
#                </a>
#               </h2>
#               <div class="sc-1v1d5rx-5 kPePTy">
#                <span>
#                 （首發美妝版純屬分享謝謝🥺），在網路上看到莫莉推薦這間清粉刺就被推坑🤣，以前用過一些粉刺面膜、粉刺貼商品都覺得沒效，用完後甚至會出現泛紅刺痛的現象，等於20年來有清跟沒清一樣🥺，化妝浮粉超級嚴重
#                </span>
#               </div>
#              </div>
#              <div class="sc-1v1d5rx-7 ghkmQW">
#               <div class="sc-1v1d5rx-8 eNmiGi">
#                <div class="sc-1kuvyve-0 HPJWH">
#                 <div class="sc-1kuvyve-1 ifcbUA" opacity="0.75">
#                  <span class="sc-1rm1ozc-0 drkUgx sc-1kuvyve-2 cdwOPp" size="20">
#                   <img alt="愛心" src="/_next/static/images/heartGray-24-1ff8eda3261bd083777921953c7f3037.png" srcset="/_next/static/images/heartGray-24-1ff8eda3261bd083777921953c7f3037.png 24w,/_next/static/images/heartGray-48-657c483b60cd8b88d3b25daf374d1b4a.png 48w"/>
#                  </span>
#                 </div>
#                 <div class="sc-1kuvyve-3 ejolKO">
#                  706
#                 </div>
#                </div>
#               </div>
#               <div class="sc-1v1d5rx-8 eNmiGi">
#                <span class="sc-1v1d5rx-9 jpuLiM">
#                 回應
#                </span>
#                <span>
#                 41
#                </span>
#               </div>
#               <div class="sc-1v1d5rx-8 eNmiGi">
#                <span class="sc-1rm1ozc-0 drkUgx sc-1v1d5rx-10 kHTcQX" role="img" size="20">
#                 <svg viewbox="0 0 24 24">
#                  <path d="M17.65 21.39L12 17.5l-5.65 3.88A1.5 1.5 0 014 20.15V5a2.5 2.5 0 012.5-2.5h11A2.5 2.5 0 0120 5v15.15a1.5 1.5 0 01-2.35 1.24z">
#                  </path>
#                 </svg>
#                </span>
#                <span>
#                 收藏
#                </span>
#               </div>
#              </div>
#              <img alt="" class="t5f2fb-0 kSmyau sc-1v1d5rx-12 hNEazt" height="84px" loading="lazy" src="https://megapx-assets.dcard.tw/images/e497c511-2448-4b39-944f-e396a348f567/160.jpeg" width="84px"/>
#             </article>
#            </div>
#           </div>
#           <div style="display:block">
#            <div class="sc-1gvwjik-0 jlApBe">
#             <div class="sc-8n4pv8-0 fOXphs">
#              <svg height="100%" preserveaspectratio="none" viewbox="0 0 100 100" width="100%">
#               <defs>
#                <lineargradient gradientunits="userSpaceOnUse" id="lg" x1="-100%" x2="200%" y1="0" y2="0">
#                 <stop class="sc-14tf9lo-0 ldLPex" stop-color="#e3e3e3">
#                  <animate attributename="offset" dur="1s" repeatcount="indefinite" values="0;0.8">
#                  </animate>
#                 </stop>
#                 <stop class="sc-14tf9lo-1 dIaplZ" stop-color="#f5f5f5">
#                  <animate attributename="offset" dur="1s" repeatcount="indefinite" values="0.1;0.9">
#                  </animate>
#                 </stop>
#                 <stop class="sc-14tf9lo-0 ldLPex" stop-color="#e3e3e3">
#                  <animate attributename="offset" dur="1s" repeatcount="indefinite" values="0.2;1">
#                  </animate>
#                 </stop>
#                </lineargradient>
#               </defs>
#               <g fill="url(#lg)">
#                <rect height="16" width="30" x="0" y="0">
#                </rect>
#                <rect height="16" width="95" x="0" y="28">
#                </rect>
#                <rect height="16" width="50" x="0" y="56">
#                </rect>
#                <rect height="16" width="35" x="0" y="84">
#                </rect>
#               </g>
#              </svg>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="sc-1szhyqg-3 iGPfkn">
#      <aside class="oboeui-0 dbBhGd">
#       <div class="sc-1j27smc-0 dHASZY" style="height:250px;width:300px">
#       </div>
#       <div class="sc-1j27smc-0 dHASZY" style="height:250px;width:300px">
#       </div>
#       <iframe class="wk6ojg-0 cgnsFz" src="//www.facebook.com/plugins/likebox.php?href=http://www.facebook.com%2Fdcard.tw&amp;width&amp;height=220&amp;show_facepile=false" title="Facebook">
#       </iframe>
#       <div class="sc-1j27smc-0 dHASZY" style="height:600px;width:300px">
#       </div>
#       <div class="sc-1j27smc-0 dHASZY" style="height:250px;width:300px">
#       </div>
#       <div class="sc-1j27smc-0 dHASZY" style="height:600px;width:300px">
#       </div>
#       <div class="eygvu1-0 gwveYV">
#        <a class="eygvu1-1 hSxPcH" href="/terms" target="_blank">
#         服務條款
#        </a>
#        <a class="eygvu1-1 hSxPcH" href="https://faq.dcard.tw/" target="_blank">
#         常見問題
#        </a>
#        <a class="eygvu1-1 hSxPcH" href="/brand/dcard_brand_guidelines.pdf" target="_blank">
#         品牌識別
#        </a>
#        <a class="eygvu1-1 hSxPcH" href="https://join.dcard.today" target="_blank">
#         徵才
#        </a>
#        <a class="eygvu1-1 hSxPcH" href="/cdn-cgi/l/email-protection#e0829593898e859393a08483819284ce8383">
#         商業合作
#        </a>
#       </div>
#      </aside>
#     </div>
#    </div>
#   </div>
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TWLTW4M" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js">
#   </script>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"pageProps":{"layoutInitialProps":{"layoutInitialProps":{"layoutInitialProps":{},"componentInitialProps":{}},"componentInitialProps":{}},"componentInitialProps":{"query":{},"paginationOptions":{"forumAlias":"all"},"country":"TW","tabs":[{"uiType":"dropdown","alias":"all","name":"全部","listType":"legacy","uiPayload":{"dropdownItems":[{"uiType":"button","alias":"hot","name":"熱門","listType":"legacy","isHome":false},{"uiType":"button","alias":"latest","name":"最新","listType":"legacy","isHome":false}]},"isHome":false},{"uiType":"button","alias":"subscribe","name":"追蹤","listType":"legacy","isHome":false}],"isForumRulePage":false}},"isLogin":false,"isMobile":false,"initialState":{"adItem":{"data":{},"error":null,"loading":false,"fetched":false},"adUnit":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{}},"app":{"data":{"isLogin":false,"isMobile":false,"ipCountry":"TW"},"error":null,"loading":false,"fetched":false},"auth":{"socialLogin":{}},"banner":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{}},"channel":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{},"unread":0},"collection":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{}},"comment":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{}},"commentDraft":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{}},"configs":{"data":{},"error":null,"loading":false,"fetched":false},"country":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{}},"dadasCampaign":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{}},"dadasCampaignStatus":{"data":{},"error":null,"loading":false,"fetched":false},"dadasSurveyTeam":{"data":{},"error":null,"loading":false,"fetched":false},"dcard":{"data":{},"error":null,"loading":false,"fetched":false},"delayModal":{"stack":[]},"department":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{}},"email":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{}},"extension":{"data":{"5bc6af9ccf56b9210bc04898-topic--2":{"created":1539747740078,"updated":1540451003823,"type":"topic","index":-2,"id":"5bc6af9ccf56b9210bc04898-topic--2"},"5e1843aad66bd07bdd7b864f-banner--1":{"created":1578648490229,"updated":1578999209560,"type":"banner","index":-1,"id":"5e1843aad66bd07bdd7b864f-banner--1","payload":{"queries":{"rank":0,"country":"TW"}}},"5e44c11d3a1b078325be8281-featuredPosts-3":{"created":1581564189322,"updated":1581564189322,"type":"featuredPosts","index":3,"id":"5e44c11d3a1b078325be8281-featuredPosts-3"},"5bc6af53cf56b970d9c04894-story-4":{"created":1539747667606,"updated":1576749681527,"type":"story","index":4,"payload":{"type":"popular"},"id":"5bc6af53cf56b970d9c04894-story-4"},"5ddb44496ee58b01d342e1f4-post-5":{"created":1574650953749,"updated":1580978431475,"type":"post","index":5,"id":"5ddb44496ee58b01d342e1f4-post-5"},"5e71d1d330bf473bc8f8f367-searchForums-7":{"created":1584517587695,"updated":1584517587695,"type":"searchForums","index":7,"id":"5e71d1d330bf473bc8f8f367-searchForums-7"},"5ddb44d9955d1a8534d56158-post-11":{"created":1574651097375,"updated":1574651097375,"type":"post","index":11,"id":"5ddb44d9955d1a8534d56158-post-11"},"5ddb4505955d1a581fd5615b-post-15":{"created":1574651141231,"updated":1574651141231,"type":"post","index":15,"id":"5ddb4505955d1a581fd5615b-post-15"}},"error":null,"pag ...
#   </script>
#   <script nomodule="" src="/_next/static/runtime/polyfills-c4620447e85e7652d141.js">
#   </script>
#   <script async="" data-next-page="/forum" src="/_next/static/ZJLDskLoICU9r7VrXbrt5/pages/forum.js">
#   </script>
#   <script async="" data-next-page="/_app" src="/_next/static/ZJLDskLoICU9r7VrXbrt5/pages/_app.js">
#   </script>
#   <script async="" src="/_next/static/chunks/a2ae04b7a833ed6fd1ce37130abd264ebd97e830.721e3a1b965b2cf4be57.js">
#   </script>
#   <script async="" src="/_next/static/chunks/146.5ccb13937f1f3b3b6f4d.js">
#   </script>
#   <script async="" src="/_next/static/chunks/156.64cc388ad91eae549273.js">
#   </script>
#   <script async="" src="/_next/static/chunks/98.e183d88064080baec759.js">
#   </script>
#   <script async="" src="/_next/static/chunks/fe8bb93dcba62e8ce8a062d724dbc8a69309bd57.930e22bd9a6baaeeb6d9.js">
#   </script>
#   <script async="" src="/_next/static/chunks/106.341a75490d857b4cc4e0.js">
#   </script>
#   <script async="" src="/_next/static/chunks/97.4f02369a917bab6a1b87.js">
#   </script>
#   <script async="" src="/_next/static/chunks/170.8858b4307afa833f270f.js">
#   </script>
#   <script async="" src="/_next/static/chunks/134.a818cdbf390fbd0075d3.js">
#   </script>
#   <script async="" src="/_next/static/runtime/webpack-7d865a61ea4e63fb5f6e.js">
#   </script>
#   <script async="" src="/_next/static/chunks/framework.b347b462804689eaf927.js">
#   </script>
#   <script async="" src="/_next/static/chunks/commons.45acb83afe343f7bf750.js">
#   </script>
#   <script async="" src="/_next/static/chunks/36db37cdb824ac796683e509104b86432ac56cc9.db9adb3fe9fc5ee59be2.js">
#   </script>
#   <script async="" src="/_next/static/chunks/60a920ca059d9b881f6db9291d2f6bc362bfb974.20a03db3388401ee95f0.js">
#   </script>
#   <script async="" src="/_next/static/chunks/6dad67ea987122f633dbe33c87f65948ae22f8c2.0623b2cd3f14b0f24cc1.js">
#   </script>
#   <script async="" src="/_next/static/chunks/22230e2425155829492db097cd516b17f80bb0f3.14e32f33d191dfcf7fb1.js">
#   </script>
#   <script async="" src="/_next/static/chunks/4416b39c1b1e4a90c10166cacaa276c0c48fc3c4.01c55215381ba964a2bc.js">
#   </script>
#   <script async="" src="/_next/static/chunks/69adf62b98132256540c758f2eb6e506cf39b1aa.795f9a2230e82309b291.js">
#   </script>
#   <script async="" src="/_next/static/runtime/main-6aae1a096c1b9125a44d.js">
#   </script>
#   <script async="" src="/_next/static/chunks/c78d26b1.c961fb3be4c3a9b50951.js">
#   </script>
#   <script async="" src="/_next/static/chunks/21f1fdb41020907fa53ac8dcc55900f482807900.e11c84f9eeaec5008989.js">
#   </script>
#   <script async="" src="/_next/static/chunks/37b3cea8be60c06a6ad2432b64f46b6a6963e728.4517cc2dbfc38027fd67.js">
#   </script>
#   <script async="" src="/_next/static/chunks/f8ff3ace8f4a6bcca4321e0aefe01ad4b0be3ae9.7f5fadc9db091ba90e80.js">
#   </script>
#   <script async="" src="/_next/static/chunks/ba85f0706285d2608ffb52e0c5a5cb9dd9b6a546.6c8829ea2b05fddd84b8.js">
#   </script>
#   <script async="" src="/_next/static/chunks/249c150c4efea44fda9ec4fabd3105e5518cc1fe.d830befc0b30c9a96591.js">
#   </script>
#   <script async="" src="/_next/static/chunks/0fc779a4777b0c6a1e6b8363b1642d83be29aee9.0d1586125a03dedda55c.js">
#   </script>
#   <script async="" src="/_next/static/chunks/52fc32bf5cf78f153a7a60263a8e279bda882f12.1048ac2c5d46189ee7c5.js">
#   </script>
#   <script async="" src="/_next/static/chunks/3a5f56208475ad3f306186d53f743ee5fb803ede.2ab3a32f71da0a7d7266.js">
#   </script>
#   <script async="" src="/_next/static/ZJLDskLoICU9r7VrXbrt5/_buildManifest.js">
#   </script>
#   <script async="" src="/_next/static/ZJLDskLoICU9r7VrXbrt5/_ssgManifest.js">
#   </script>
#  </body>
# </html>

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ### 經過轉換，原本是str的HTML，已經被轉換成bs4的物件。下面列出一些bs4物件的屬性和方法

# %%
soup.title
# Out:
# <title>Dcard</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.string
# Out:
# 'Dcard'

# %%
soup.a
# Out:
# <a class="sc-1h3w01r-0 BYkrm" href="/f" title="Dcard"><img alt="Dcard" class="ezgous-0 ktvxUR" src="/_next/static/images/logo-6c547910a47669647856d4c9cc62f0ba.svg"/></a>

# %%
soup.find('a')
# Out:
# <a class="sc-1h3w01r-0 BYkrm" href="/f" title="Dcard"><img alt="Dcard" class="ezgous-0 ktvxUR" src="/_next/static/images/logo-6c547910a47669647856d4c9cc62f0ba.svg"/></a>

# %% [markdown]
# ### 抓出超連結中的網址

# %%
a_list = soup.find_all("a")
for i in range(20):
    print(a_list[i].get('href'))
# Out:
# /f
# /signup?redirect=%2Ff
# None
# /forum/all
# /forum/popular
# /goods
# /f
# /f?pessoal=true
# /f/mood/p/233415762
# /f/funny/p/233417043
# /f/relationship/p/233421692
# /f/funny/p/233418387
# /f/girl/p/233417045
# /f/makeup/p/233418196
# /f/relationship/p/233417830
# /f/relationship/p/233415760
# /f/2019_ncov/p/233417727
# /f/2019_ncov/p/233417893
# /f/funny/p/233416223
# /f/relationship/p/233416712

# %% [markdown]
# ### 可以設定參數，來查找特定tag
#
# ### 列出Dard十大熱門文章及其網址

# %%
soup.find_all('a', class_='sc-1v1d5rx-4 cJzlcl')
# Out:
# [<a class="sc-1v1d5rx-4 cJzlcl" href="/f/mood/p/233415762"><span>在google地圖上看到已逝的外婆👵🏻</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/funny/p/233417043"><span>不要太誠實也不要太得寸進尺</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/relationship/p/233421692"><span>原來被愛真的很輕鬆</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/funny/p/233418387"><span>店員一定有偷笑ಥ‿ಥ</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/girl/p/233417045"><span>室友自慰被我發現</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/makeup/p/233418196"><span>我經歷了一場浩劫🤨</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/relationship/p/233417830"><span>#圖文 暫時分開</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/relationship/p/233415760"><span>女孩們請找一個真心愛妳的</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/2019_ncov/p/233417727"><span>台灣送荷蘭橘色口罩，暖到哭</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/2019_ncov/p/233417893"><span>家裡有3000片口罩是正常的嗎？</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/funny/p/233416223"><span>同學兩兩一組喔</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/relationship/p/233416712"><span>男友到底想怎樣？</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/rainbow/p/233416937"><span>姊姊這種生物 告白禮</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/girl/p/233417782"><span>我真希望我是男的</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/youtuber/p/233419676"><span>關於哈哈台-水源希子巴黎世家特輯</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/girl/p/233415804"><span>youtuber開始對拍片失去熱情?</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/trending/p/233417949"><span>蔡依林不該輕易被定調為舔共</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/2019_ncov/p/233417254"><span>學校是防疫漏洞</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/relationship/p/233419197"><span>我們真的分手了</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/funny/p/233416116"><span>可愛的KTV服務員</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/trending/p/233415961"><span>台灣送荷蘭橘色口罩，讓網友大讚好暖心</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/entertainer/p/233416917"><span>#集中討論 （G)I-DLE-Oh my god 回歸MV</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/trending/p/233417923"><span>戶戶送停止台灣營運通知</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/entertainer/p/233423166"><span>蘇志燮結婚了！！</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/food/p/233419647"><span>#圖  帶省吃儉用爸媽吃鼎泰豐</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/relationship/p/233419122"><span>套套破掉 屁股痛(微西斯)</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/food/p/233419497"><span>好市多亂亂買feat.肥死你🐷</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/funny/p/233417982"><span>學生們讓人無法理解的作業（二）</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/relationship/p/233418371"><span>我女友有些時候真的很可愛😏</span></a>,
#  <a class="sc-1v1d5rx-4 cJzlcl" href="/f/makeup/p/233417281"><span>台北清粉刺 #內含20年粉刺圖</span></a>]

# %% [markdown]
# ### 利用```str.split()```，從網址中擷取出文章ID

# %%
a = soup.find('a', class_='sc-1v1d5rx-4 cJzlcl')
a
# Out:
# <a class="sc-1v1d5rx-4 cJzlcl" href="/f/mood/p/233415762"><span>在google地圖上看到已逝的外婆👵🏻</span></a>

# %% [markdown]
# ### 取出html tag的網址

# %%
href = a.get('href')
href
# Out:
# '/f/mood/p/233415762'

# %%
href.split('/')
# Out:
# ['', 'f', 'mood', 'p', '233415762']

# %%
article_id = href.split('/')[-1]
article_id
# Out:
# '233415762'

# %% [markdown]
# ### 利用for loop列出熱門前十的文章標題、文章ID及文章網址

# %%
title = soup.find_all('a', class_='sc-1v1d5rx-4 cJzlcl')
for i in range(10):
    print(title[i].string)
    print("文章ID:" + title[i].get('href').split('/')[-1])
    print("文章網址： https://www.dcard.tw{}".format(title[i].get('href')))
    print()
# Out:
# 在google地圖上看到已逝的外婆👵🏻
# 文章ID:233415762
# 文章網址： https://www.dcard.tw/f/mood/p/233415762
#
# 不要太誠實也不要太得寸進尺
# 文章ID:233417043
# 文章網址： https://www.dcard.tw/f/funny/p/233417043
#
# 原來被愛真的很輕鬆
# 文章ID:233421692
# 文章網址： https://www.dcard.tw/f/relationship/p/233421692
#
# 店員一定有偷笑ಥ‿ಥ
# 文章ID:233418387
# 文章網址： https://www.dcard.tw/f/funny/p/233418387
#
# 室友自慰被我發現
# 文章ID:233417045
# 文章網址： https://www.dcard.tw/f/girl/p/233417045
#
# 我經歷了一場浩劫🤨
# 文章ID:233418196
# 文章網址： https://www.dcard.tw/f/makeup/p/233418196
#
# #圖文 暫時分開
# 文章ID:233417830
# 文章網址： https://www.dcard.tw/f/relationship/p/233417830
#
# 女孩們請找一個真心愛妳的
# 文章ID:233415760
# 文章網址： https://www.dcard.tw/f/relationship/p/233415760
#
# 台灣送荷蘭橘色口罩，暖到哭
# 文章ID:233417727
# 文章網址： https://www.dcard.tw/f/2019_ncov/p/233417727
#
# 家裡有3000片口罩是正常的嗎？
# 文章ID:233417893
# 文章網址： https://www.dcard.tw/f/2019_ncov/p/233417893

# %% [markdown]
# ## API方式示範：Dcard

# %% [markdown]
# 之前的做法只能取出約30多筆的資料

# %%
url = "https://www.dcard.tw/f/mood/p/233377179"
resp = requests.get(url)
resp.status_code
# Out:
# 200

# %%
html = resp.text
html = BeautifulSoup(html, "lxml")

# %%
len(html.find_all("div", class_="sc-1wrppqn-3 fIdNgN"))
# Out:
# 33

# %%
html.find_all("div", class_="sc-1wrppqn-3 fIdNgN")
# Out:
# [<div class="sc-1wrppqn-3 fIdNgN">國立臺灣大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">中國醫藥大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立雲林科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立雲林科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立臺灣大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">中國醫藥大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">鯊魚養殖戶</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">新北倉鼠系</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">中國文化大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">這則回應已被刪除</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">高苑科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">僑光科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立交通大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">耕莘健康管理專科學校</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">致理科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">輔英科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立中央大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">高雄醫學大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立政治大學 法律研究所</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">臺北城市科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立中正大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">致理科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">長榮大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立臺北商業大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">朝陽科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">健行科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">朝陽科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立臺中科技大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">長榮大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">輔仁大學</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立臺中科技大學 應用英語系</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">麻瓜燉雞</div>,
#  <div class="sc-1wrppqn-3 fIdNgN">國立高雄科技大學</div>]

# %% [markdown]
# ### 使用api去資料

# %%
article_id = "233377179" 
dcard_api = "https://www.dcard.tw/service/api/v2/posts/{}/comments".format(article_id)

header = {'user-agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'}
resp = requests.get(dcard_api, headers=header)
print(resp.url)
print()
print(resp.text)
# Out:
# https://www.dcard.tw/service/api/v2/posts/233377179/comments
#
# [{"id":"1f4c8e1f-a48f-4d9a-8b7f-7f88fda4c847","anonymous":true,"postId":233377179,"createdAt":"2020-03-30T19:53:32.993Z","updatedAt":"2020-03-30T19:53:32.993Z","floor":1,"content":"妳和你哥都辛苦了  加油","likeCount":5281,"withNickname":false,"hiddenByAuthor":false,"meta":{},"gender":"M","school":"國立雲林科技大學","host":false,"reportReason":"","mediaMeta":[],"hidden":false,"inReview":false,"reportReasonText":"","isSuspiciousAccount":false,"postAvatar":""},{"id":"7c91dc95-84a6-4679-b04b-cd9d030fd7b6","anonymous":true,"postId":233377179,"createdAt":"2020-03-30T20:15:39.247Z","updatedAt":"2020-04-01T05:56:09.545Z","floor":2,"content":"妹妹，要不要給我玩？已哭(日文)","likeCount":7803,"withNickname":false,"hiddenByAuthor":false,"meta":{},"gender":"M","school":"國立臺灣大學","host":false,"reportReason":"","mediaMeta":[],"hidden":false,"inReview":false,"reportReasonText":"","isSuspiciousAccount":false,"postAvatar":""},{"id":"8a172145-4c36-4859-8c4c-9a0284e658ca","anonymous":true,"postId":233377179,"createdAt":"2020-03-30T20:24:05.504Z","updatedAt":"2020-03-30T20:24:05.504Z","floor":3,"content":"真是一個滿分的妹妹………","likeCount":5353,"withNickname":false,"hiddenByAuthor":false,"meta":{},"gender":"M","school":"中國醫藥大學","host":false,"reportReason":"","mediaMeta":[],"hidden":false,"inReview":false,"reportReasonText":"","isSuspiciousAccount":false,"postAvatar":""},{"id":"cdd73c45-2a6d-443e-9cdc-d8cefca1120e","anonymous":false,"postId":233377179,"createdAt":"2020-03-30T21:30:37.743Z","updatedAt":"2020-03-30T21:30:37.743Z","floor":4,"content":"都辛苦了\n你是個很好的妹妹\n別給自己太大的壓力\n感覺妳已經很棒了","likeCount":638,"withNickname":true,"hiddenByAuthor":false,"meta":{},"gender":"F","school":"鯊魚養殖戶","department":"chin_yu","host":false,"reportReason":"","mediaMeta":[],"hidden":false,"inReview":false,"reportReasonText":"","isSuspiciousAccount":false,"postAvatar":""},{"id":"a6134ff7-5421-49c8-a0ca-e14a82f899f3","anonymous":false,"postId":233377179,"createdAt":"2020-03-30T21:34:10.255Z","updatedAt":"2020-03-30T21:34:10.255Z","floor":5,"content":"辛苦了，你很棒","likeCount":181,"withNickname":true,"hiddenByAuthor":false,"meta":{},"gender":"F","school":"新北倉鼠系","department":"milk_0711","host":false,"reportReason":"","mediaMeta":[],"hidden":false,"inReview":false,"reportReasonText":"","isSuspiciousAccount":false,"postAvatar":""},{"id":"45093d81-a1a8-44a4-9cee-56faf333a103","anonymous":true,"postId":233377179,"createdAt":"2020-03-30T23:32:35.230Z","updatedAt":"2020-03-30T23:32:35.230Z","floor":6,"content":"你是一個好妹妹，辛苦你了，要加油唷","likeCount":201,"withNickname":false,"hiddenByAuthor":false,"meta":{},"gender":"F","school":"中國文化大學","host":false,"reportReason":"","mediaMeta":[],"hidden":false,"inReview":false,"reportReasonText":"","isSuspiciousAccount":false,"postAvatar":""},{"id":"b8bd2d94-8643-431d-9b60-3ba0b924f020","anonymous":false,"postId":233377179,"createdAt":"2020-03-31T00:05:07.517Z","updatedAt":"2020-03-31T00:05:07.517Z","floor":7,"withNickname":false,"hiddenByAuthor":true,"meta":{},"host":false,"reportReason":"","mediaMeta":[],"hidden":true,"inReview":false,"reportReasonText":"","isSuspiciousAccount":false,"postAvatar":""},{"id":"b2dcaebe-99ee-4930-aec9-11d5aa2d43b7","anonymous":true,"postId":233377179,"createdAt":"2020-03-31T00:05:34.162Z","updatedAt":"2020-03-31T00:05:34.162Z","floor":8,"content":"辛苦妳了，妳哥哥也是\n\n加油加油努力過好每一天💪💪","likeCount":138,"withNickname":false,"hiddenByAuthor":false,"meta":{},"gender":"M","school":"高苑科技大學","host":false,"reportReason":"","mediaMeta":[],"hidden":false,"inReview":false,"reportReasonText":"","isSuspiciousAccount":false,"postAvatar":""},{"id":"9980882a-4621-4bf9-9261-b71d2cc1e3f4","anonymous":false,"postId":233377179,"createdAt":"2020-03-31T00:43:26.471Z","updatedAt":"2020-03-31T00:43:26.471Z","floor":9,"content":"你很好！是哥哥的天使！更是哥哥的全部","likeCount":260,"withNickname":true,"hiddenByAuthor":false,"meta":{},"gender":"M","school":"僑光科技大學","department":"okevin_d","host":false,"reportReason":"","mediaMeta":[],"hidden":false,"inReview":false,"reportReasonText":"","isSuspiciousAccount":false,"postA ...

# %% [markdown]
# ### 用JSON的方式呈現

# %%
resp.json()
# Out:
# [{'id': '1f4c8e1f-a48f-4d9a-8b7f-7f88fda4c847',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T19:53:32.993Z',
#   'updatedAt': '2020-03-30T19:53:32.993Z',
#   'floor': 1,
#   'content': '妳和你哥都辛苦了  加油',
#   'likeCount': 5281,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立雲林科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '7c91dc95-84a6-4679-b04b-cd9d030fd7b6',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T20:15:39.247Z',
#   'updatedAt': '2020-04-01T05:56:09.545Z',
#   'floor': 2,
#   'content': '妹妹，要不要給我玩？已哭(日文)',
#   'likeCount': 7803,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立臺灣大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '8a172145-4c36-4859-8c4c-9a0284e658ca',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T20:24:05.504Z',
#   'updatedAt': '2020-03-30T20:24:05.504Z',
#   'floor': 3,
#   'content': '真是一個滿分的妹妹………',
#   'likeCount': 5353,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '中國醫藥大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'cdd73c45-2a6d-443e-9cdc-d8cefca1120e',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T21:30:37.743Z',
#   'updatedAt': '2020-03-30T21:30:37.743Z',
#   'floor': 4,
#   'content': '都辛苦了\n你是個很好的妹妹\n別給自己太大的壓力\n感覺妳已經很棒了',
#   'likeCount': 638,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '鯊魚養殖戶',
#   'department': 'chin_yu',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'a6134ff7-5421-49c8-a0ca-e14a82f899f3',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T21:34:10.255Z',
#   'updatedAt': '2020-03-30T21:34:10.255Z',
#   'floor': 5,
#   'content': '辛苦了，你很棒',
#   'likeCount': 181,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '新北倉鼠系',
#   'department': 'milk_0711',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '45093d81-a1a8-44a4-9cee-56faf333a103',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T23:32:35.230Z',
#   'updatedAt': '2020-03-30T23:32:35.230Z',
#   'floor': 6,
#   'content': '你是一個好妹妹，辛苦你了，要加油唷',
#   'likeCount': 201,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '中國文化大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'b8bd2d94-8643-431d-9b60-3ba0b924f020',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T00:05:07.517Z',
#   'updatedAt': '2020-03-31T00:05:07.517Z',
#   'floor': 7,
#   'withNickname': False,
#   'hiddenByAuthor': True,
#   'meta': {},
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': True,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'b2dcaebe-99ee-4930-aec9-11d5aa2d43b7',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T00:05:34.162Z',
#   'updatedAt': '2020-03-31T00:05:34.162Z',
#   'floor': 8,
#   'content': '辛苦妳了，妳哥哥也是\n\n加油加油努力過好每一天💪💪',
#   'likeCount': 138,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '高苑科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '9980882a-4621-4bf9-9261-b71d2cc1e3f4',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T00:43:26.471Z',
#   'updatedAt': '2020-03-31T00:43:26.471Z',
#   'floor': 9,
#   'content': '你很好！是哥哥的天使！更是哥哥的全部',
#   'likeCount': 260,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '僑光科技大學',
#   'department': 'okevin_d',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'aa00cdef-6fad-4269-839d-29ae439bd2cb',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T01:14:13.510Z',
#   'updatedAt': '2020-03-31T01:14:13.510Z',
#   'floor': 10,
#   'content': '我姐也是智能不足\n辛苦了～',
#   'likeCount': 148,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立交通大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '2595dd43-d933-46fe-8edb-0cf1b780fdf5',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T01:37:55.039Z',
#   'updatedAt': '2020-03-31T01:37:55.039Z',
#   'floor': 11,
#   'content': '辛苦妳了 妳最棒了QQ',
#   'likeCount': 65,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '耕莘健康管理專科學校',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'e94ae3ca-3666-43f6-953d-09be8a83d8fb',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T01:45:55.917Z',
#   'updatedAt': '2020-03-31T01:45:55.917Z',
#   'floor': 12,
#   'content': '哥哥一定很謝謝有你這個好妹妹❤️',
#   'likeCount': 110,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '致理科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'e161efd9-ac2e-4a65-994c-208024f64886',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T01:46:53.437Z',
#   'updatedAt': '2020-03-31T01:46:53.437Z',
#   'floor': 13,
#   'content': '真的你好棒！你也是一個很善良的人喔 跟你哥哥果然是最好的夥伴呢o(≧v≦)o',
#   'likeCount': 122,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '輔英科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '5bf9b416-1d24-4a30-943a-23bf125ecc66',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T02:01:54.018Z',
#   'updatedAt': '2020-03-31T02:01:54.018Z',
#   'floor': 14,
#   'content': '都辛苦了♡你真的很棒！',
#   'likeCount': 53,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立中央大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'b21f10f9-98ef-4fa8-a401-76c1ca07bbc8',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T02:13:22.608Z',
#   'updatedAt': '2020-03-31T02:13:22.608Z',
#   'floor': 15,
#   'content': '你是個好妹妹',
#   'likeCount': 46,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '高雄醫學大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'a33a29fc-c7f0-42b2-b043-5e0be7ead88b',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T02:23:10.263Z',
#   'updatedAt': '2020-03-31T02:23:10.263Z',
#   'floor': 16,
#   'content': '文筆好好\n妳是一個很棒的妹妹\n也謝謝妳的這篇文章\n讓人覺得心裡暖洋洋的\n妳們都是心地善良的小天使',
#   'likeCount': 307,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立政治大學',
#   'department': '法律研究所',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '1953b3a7-e185-481f-a33f-b056b1a1b874',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T02:40:51.653Z',
#   'updatedAt': '2020-03-31T02:40:51.653Z',
#   'floor': 17,
#   'content': '加油',
#   'likeCount': 25,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '臺北城市科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '13a14d36-225b-4b41-8424-599878a1cc53',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T02:52:05.512Z',
#   'updatedAt': '2020-03-31T02:52:05.512Z',
#   'floor': 18,
#   'content': '老闆⋯⋯我的早餐你怎麼加那麼多生洋蔥⋯⋯',
#   'likeCount': 202,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立中正大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '7703069e-527b-4b95-bcaf-87306dbc1d62',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:01:44.512Z',
#   'updatedAt': '2020-03-31T03:01:44.512Z',
#   'floor': 19,
#   'content': '只是喝杯奶茶怎麼沒味道...\n啊抱歉我眼淚滴太多了',
#   'likeCount': 169,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '致理科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '189548ff-c2d1-4bb0-be5c-ccdfaf555c9e',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:02:08.444Z',
#   'updatedAt': '2020-03-31T03:02:08.444Z',
#   'floor': 20,
#   'content': '看到標題以為是母湯的',
#   'likeCount': 130,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '長榮大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'd5002f85-36e8-4623-99c6-f211789260a2',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:07:17.609Z',
#   'updatedAt': '2020-03-31T03:07:17.609Z',
#   'floor': 21,
#   'content': '我的課本上都是我的淚😭',
#   'likeCount': 66,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立臺北商業大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'c36ad4f0-ae74-41d1-8523-092f07177879',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:07:17.884Z',
#   'updatedAt': '2020-03-31T03:07:17.884Z',
#   'floor': 22,
#   'content': '（抱',
#   'likeCount': 23,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '朝陽科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'b2bebbcf-f4c2-4684-9214-565311914b45',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:11:30.775Z',
#   'updatedAt': '2020-03-31T03:11:30.775Z',
#   'floor': 23,
#   'content': '好暖心喔！反而是當媽媽的怎麼都會把情緒發洩小孩身上 很舒壓？媽的！因為我也是被媽媽時常發洩情緒勒索我',
#   'likeCount': 92,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '健行科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'e9d6ae42-b3ae-42d1-9b24-d66919378251',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:12:37.710Z',
#   'updatedAt': '2020-03-31T03:12:37.710Z',
#   'floor': 24,
#   'content': '你真的好棒\n願世人能善待你們的溫柔善良',
#   'likeCount': 65,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '朝陽科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '4adde8af-4abc-498c-8c13-c3d8eab607a7',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:16:22.358Z',
#   'updatedAt': '2020-03-31T03:16:22.358Z',
#   'floor': 25,
#   'content': '校園裡面有你這麼溫暖的人真好🧡\n哥哥不幸中的大幸就是擁有你這個妹妹\n要好好繼續加油哦！',
#   'likeCount': 60,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立臺中科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'c6d9875e-5b8c-4901-8ab5-5a9e140cf1de',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:17:55.970Z',
#   'updatedAt': '2020-03-31T03:17:55.970Z',
#   'floor': 26,
#   'content': '妳也是善良溫暖的人呀☺️',
#   'likeCount': 39,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '長榮大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '7e5f5f1d-b220-41ff-bd37-3757b083a2f3',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:23:27.756Z',
#   'updatedAt': '2020-03-31T03:23:27.756Z',
#   'floor': 27,
#   'content': '辛苦你了！你要了解哥哥並不是你的責任，所以不要讓自己壓力太大！你的善良與愛，世界不會虧待你的🥰🥰😍😍',
#   'likeCount': 47,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '輔仁大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '8c24767b-9dab-4c28-9995-a4c7a8f4943b',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:28:12.458Z',
#   'updatedAt': '2020-03-31T03:28:12.458Z',
#   'floor': 28,
#   'content': '辛苦了！加油！妳很棒！',
#   'likeCount': 9,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立臺中科技大學',
#   'department': '應用英語系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '5903874d-7493-4ff7-b68f-09592c20d0a8',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:35:20.296Z',
#   'updatedAt': '2020-03-31T03:36:30.016Z',
#   'floor': 29,
#   'content': '我們無時無刻不在成長中，\n成長的每個階段，難免會有不同的想法，\n重要的是，後來的我們，成為了什麼樣子。\n\n不必太過在意曾經的想法\n因為現在的你，已經是個願意為人著想，溫暖而善良的人。我們喜歡你現在的樣子。未來會變得怎麼樣，我們不知道，但只要能記住現在的感覺，那就可以了。\n\n請愉快地小步躍著前行吧～',
#   'likeCount': 153,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '麻瓜燉雞',
#   'department': 'feya13',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'c8939fcc-41ec-4988-85d1-6ec150718005',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:40:51.862Z',
#   'updatedAt': '2020-03-31T03:40:51.862Z',
#   'floor': 30,
#   'content': '妹妹 很可以喔',
#   'likeCount': 8,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立高雄科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''}]

# %%
len(resp.json())
# Out:
# 30

# %%
for i in resp.json():
    if "content" in i:
        print(i['content'])
# Out:
# 妳和你哥都辛苦了  加油
# 妹妹，要不要給我玩？已哭(日文)
# 真是一個滿分的妹妹………
# 都辛苦了
# 你是個很好的妹妹
# 別給自己太大的壓力
# 感覺妳已經很棒了
# 辛苦了，你很棒
# 你是一個好妹妹，辛苦你了，要加油唷
# 辛苦妳了，妳哥哥也是
#
# 加油加油努力過好每一天💪💪
# 你很好！是哥哥的天使！更是哥哥的全部
# 我姐也是智能不足
# 辛苦了～
# 辛苦妳了 妳最棒了QQ
# 哥哥一定很謝謝有你這個好妹妹❤️
# 真的你好棒！你也是一個很善良的人喔 跟你哥哥果然是最好的夥伴呢o(≧v≦)o
# 都辛苦了♡你真的很棒！
# 你是個好妹妹
# 文筆好好
# 妳是一個很棒的妹妹
# 也謝謝妳的這篇文章
# 讓人覺得心裡暖洋洋的
# 妳們都是心地善良的小天使
# 加油
# 老闆⋯⋯我的早餐你怎麼加那麼多生洋蔥⋯⋯
# 只是喝杯奶茶怎麼沒味道...
# 啊抱歉我眼淚滴太多了
# 看到標題以為是母湯的
# 我的課本上都是我的淚😭
# （抱
# 好暖心喔！反而是當媽媽的怎麼都會把情緒發洩小孩身上 很舒壓？媽的！因為我也是被媽媽時常發洩情緒勒索我
# 你真的好棒
# 願世人能善待你們的溫柔善良
# 校園裡面有你這麼溫暖的人真好🧡
# 哥哥不幸中的大幸就是擁有你這個妹妹
# 要好好繼續加油哦！
# 妳也是善良溫暖的人呀☺️
# 辛苦你了！你要了解哥哥並不是你的責任，所以不要讓自己壓力太大！你的善良與愛，世界不會虧待你的🥰🥰😍😍
# 辛苦了！加油！妳很棒！
# 我們無時無刻不在成長中，
# 成長的每個階段，難免會有不同的想法，
# 重要的是，後來的我們，成為了什麼樣子。
#
# 不必太過在意曾經的想法
# 因為現在的你，已經是個願意為人著想，溫暖而善良的人。我們喜歡你現在的樣子。未來會變得怎麼樣，我們不知道，但只要能記住現在的感覺，那就可以了。
#
# 請愉快地小步躍著前行吧～
# 妹妹 很可以喔

# %% [markdown]
# ### 查看30樓以後的留言

# %%
floor = 30
url = "https://www.dcard.tw/service/api/v2/posts/233377179/comments?after={}".format(floor)

resp = requests.get(url)
resp.json()
# Out:
# [{'id': 'fa35f5f2-1198-4b9e-b314-ab3577a9ee7e',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:46:56.225Z',
#   'updatedAt': '2020-03-31T03:46:56.225Z',
#   'floor': 31,
#   'content': 'B23 媽媽應該也很痛苦吧？\n光是照顧一個正常的孩子都足以讓父母崩潰了，何況是一個智能不足的小孩，我看過很多那樣的家庭，他們真的很辛苦，不論金錢、外人眼光還是什麼，總有一堆麻煩事等著他們😢😢',
#   'likeCount': 264,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '亞洲大學',
#   'department': '財務金融學系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '5b8005ca-848f-493a-89e5-cb850eaaac3d',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:54:55.281Z',
#   'updatedAt': '2020-03-31T03:54:55.281Z',
#   'floor': 32,
#   'content': '妳很棒',
#   'likeCount': 3,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '靜宜大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '1b31837c-3120-415d-b347-0377fb429dfe',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:59:56.504Z',
#   'updatedAt': '2020-03-31T04:00:20.136Z',
#   'floor': 33,
#   'content': '不知道為什麼 有些內容心境很像陽光普照電影的情節 我也是深入提到家人 情緒就會忍不住潰提',
#   'likeCount': 29,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立中興大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '3d54ba1d-03c8-4787-ab06-52189b0202f2',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:03:50.161Z',
#   'updatedAt': '2020-03-31T04:10:39.393Z',
#   'floor': 34,
#   'content': 'B33 我只是想把陽光讓給了弟弟……',
#   'likeCount': 23,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立虎尾科技大學',
#   'department': '動力機械工程系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '2542583a-818e-4488-8a5f-5ed8947bda31',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:05:04.858Z',
#   'updatedAt': '2020-03-31T04:05:04.858Z',
#   'floor': 35,
#   'content': '看標題以為你被怎麼了⋯',
#   'likeCount': 6,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '中國科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '05b97c9e-0860-418a-866b-334ee82c4817',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:09:17.857Z',
#   'updatedAt': '2020-03-31T04:09:17.857Z',
#   'floor': 36,
#   'content': '看完有種想抱著你說，你辛苦了的衝動。',
#   'likeCount': 8,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '別跟我搶餅乾',
#   'department': 'ghi159762',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '6def9ecc-d141-4161-9d8f-f341c609abcb',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:10:34.615Z',
#   'updatedAt': '2020-03-31T04:10:34.615Z',
#   'floor': 37,
#   'content': '我看到了天使(´⊙ω⊙`)',
#   'likeCount': 9,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立暨南國際大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '02384b93-2822-4927-8937-a09cfa83baba',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:15:52.287Z',
#   'updatedAt': '2020-03-31T04:15:52.287Z',
#   'floor': 38,
#   'content': 'B31 我只能說我長大才知道我媽真的超辛苦\n\n我是一個過動兒(小時候啦\n小時候造成我媽超多麻煩……(我媽是說很少發脾氣也只有我頑皮的上時候',
#   'likeCount': 28,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立虎尾科技大學',
#   'department': '動力機械工程系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'f1ae9458-7c2e-4317-a48a-42179ed12aad',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:16:53.279Z',
#   'updatedAt': '2020-03-31T04:16:53.279Z',
#   'floor': 39,
#   'content': '真暖！好妹妹！！',
#   'likeCount': 3,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立臺灣大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '89a90c44-d69a-4bc9-bd59-113ac578b6ed',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:16:59.549Z',
#   'updatedAt': '2020-03-31T04:17:41.220Z',
#   'floor': 40,
#   'content': '也許不是滿分的妹妹\n但是在你哥哥眼中永遠都會是100分的家人\n哥哥會這樣就是命運\n難過就哭吧\n但還是希望妳能勇敢的陪伴哥哥走完餘生',
#   'likeCount': 71,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立交通大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '322b0f27-78e4-4ab3-a373-dbac46e83ff0',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:27:45.977Z',
#   'updatedAt': '2020-03-31T04:27:45.977Z',
#   'floor': 41,
#   'content': '這文筆好像在看以前國文課本上會出現的文章\n雖然我沒兄弟姊妹，但深刻的描繪看了還是讓我很有感觸很想哭',
#   'likeCount': 49,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '嶺東科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '049108f7-0d20-46f5-a511-b22250275241',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:28:31.334Z',
#   'updatedAt': '2020-03-31T04:28:31.334Z',
#   'floor': 42,
#   'content': 'Do you wanna build a snowman',
#   'likeCount': 39,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立清華大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '0d707505-6608-4d44-be4a-808444e3fc57',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:30:46.600Z',
#   'updatedAt': '2020-03-31T04:30:46.600Z',
#   'floor': 43,
#   'content': '看得好想哭 你真的是個好妹妹',
#   'likeCount': 8,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '世新大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'e77409d3-ef67-43b6-85bc-d5f46d97bbbc',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:32:49.332Z',
#   'updatedAt': '2020-03-31T04:32:49.332Z',
#   'floor': 44,
#   'content': '真的眼眶泛淚🥺🥺\n親情總是最容易觸犯淚腺的地方🥺',
#   'likeCount': 15,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '僑光科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'ac511e24-f222-472a-b83d-11124792d010',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:35:17.338Z',
#   'updatedAt': '2020-03-31T04:35:17.338Z',
#   'floor': 45,
#   'content': '我怎麼覺得你哥的智商比一堆發廢文的高很多',
#   'likeCount': 88,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '逢甲大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '11bc1066-b106-4fb9-8607-979ac26cba63',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:35:30.251Z',
#   'updatedAt': '2020-03-31T04:35:30.251Z',
#   'floor': 46,
#   'content': '你很棒你哥一定很開心有你這樣的妹妹💪',
#   'likeCount': 2,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '僑光科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'caddd3db-ddc9-46eb-8c5b-0dc52803d191',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:36:50.158Z',
#   'updatedAt': '2020-03-31T04:36:50.158Z',
#   'floor': 47,
#   'content': '暖文',
#   'likeCount': 6,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '逢甲大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'e7621187-d72c-4af6-ae54-9c812eeb6f88',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:45:04.631Z',
#   'updatedAt': '2020-03-31T04:45:04.631Z',
#   'floor': 48,
#   'content': '給妳100分\n真的是一個好妹妹\n但自己壓力不要給自己太大\n加油～',
#   'likeCount': 6,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '中華醫事科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '5264cddc-b36f-49fa-a6ec-3f11d7fdf7f4',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:47:42.512Z',
#   'updatedAt': '2020-03-31T04:47:42.512Z',
#   'floor': 49,
#   'content': '他不笨他是我哥哥😭',
#   'likeCount': 38,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '迷路的人',
#   'department': 'mim',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'fa502fe1-d279-4042-bb4a-4279f27a24e9',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:47:51.996Z',
#   'updatedAt': '2020-03-31T04:47:51.996Z',
#   'floor': 50,
#   'content': '哥哥加油！！！！！！',
#   'likeCount': 3,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '修平科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'c6eabeaf-d228-492b-92b9-429cd816211a',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:51:57.511Z',
#   'updatedAt': '2020-03-31T04:51:57.511Z',
#   'floor': 51,
#   'content': '這篇洋蔥也加太多了吧QQ',
#   'likeCount': 8,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '中國文化大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'd9857f57-1eb9-4648-8081-173a7b290773',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:53:41.866Z',
#   'updatedAt': '2020-03-31T04:53:41.866Z',
#   'floor': 52,
#   'content': '看到那句如果受傷的是我就好了...\n\n心酸了一下，你真的很懂事，你是最棒的！！\n\n加油！！',
#   'likeCount': 23,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立高雄科技大學',
#   'department': '電子工程系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '6ffc3228-8e03-42d1-b49d-4264d8ec26ec',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:57:59.669Z',
#   'updatedAt': '2020-03-31T04:57:59.669Z',
#   'floor': 53,
#   'content': '平常不按愛心的 久違的又按了一個\n你們很棒 真的',
#   'likeCount': 5,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '嶺東科技大學',
#   'department': '視覺傳達設計系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '6edd65a0-3f13-49ae-b8ca-c492694103cb',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T05:03:56.495Z',
#   'updatedAt': '2020-03-31T05:03:56.495Z',
#   'floor': 54,
#   'content': '為什麼會哭啦！這篇真的是好文欸👍👍看了感觸好深',
#   'likeCount': 7,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立嘉義大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'fd2ce03d-c66a-4f55-a5b0-d5cd00e5a710',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T05:12:30.616Z',
#   'updatedAt': '2020-03-31T05:12:30.616Z',
#   'floor': 55,
#   'content': '願善良的你們會被世界溫柔相待',
#   'likeCount': 24,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立政治大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '4de777ac-8b0f-4b03-bbed-dbeec1a99329',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T05:20:56.853Z',
#   'updatedAt': '2020-03-31T05:20:56.853Z',
#   'floor': 56,
#   'content': '加油💪🏻',
#   'likeCount': 2,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '大葉大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '68c24b55-8e20-4e70-b6ff-001d11f8056d',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T05:22:06.581Z',
#   'updatedAt': '2020-03-31T05:22:06.581Z',
#   'floor': 57,
#   'content': '願你們兄妹倆一切都好❤️',
#   'likeCount': 7,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '輔仁大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'bd328e45-cff0-4858-aa3c-d36b5cdd820a',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T05:22:11.577Z',
#   'updatedAt': '2020-03-31T05:22:11.577Z',
#   'floor': 58,
#   'content': '覺得好心酸😔\n\n\n不過比起一些微西斯的垃圾廢文\n這才是適合低卡的',
#   'likeCount': 28,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '大仁科技大學',
#   'department': '藥學系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'eabf8d41-e45d-475f-bf4d-267e8f536e07',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T05:23:02.963Z',
#   'updatedAt': '2020-03-31T05:23:02.963Z',
#   'floor': 59,
#   'content': '好哥哥和超級好妹妹',
#   'likeCount': 3,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立中興大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'b6fc8080-ef69-4e9c-9498-144a66a563cd',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T05:24:14.410Z',
#   'updatedAt': '2020-03-31T05:24:14.410Z',
#   'floor': 60,
#   'content': '祝一切安好',
#   'likeCount': 2,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '紫薇不會斗數',
#   'department': 'adobe250258',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''}]

# %% [markdown]
# ### 顯示前n個樓層

# %%
floor = 50
url = "https://www.dcard.tw/service/api/v2/posts/233377179/comments?limit={}".format(floor)

resp = requests.get(url)
resp.json()
# Out:
# [{'id': '1f4c8e1f-a48f-4d9a-8b7f-7f88fda4c847',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T19:53:32.993Z',
#   'updatedAt': '2020-03-30T19:53:32.993Z',
#   'floor': 1,
#   'content': '妳和你哥都辛苦了  加油',
#   'likeCount': 5281,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立雲林科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '7c91dc95-84a6-4679-b04b-cd9d030fd7b6',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T20:15:39.247Z',
#   'updatedAt': '2020-04-01T05:56:09.545Z',
#   'floor': 2,
#   'content': '妹妹，要不要給我玩？已哭(日文)',
#   'likeCount': 7803,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立臺灣大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '8a172145-4c36-4859-8c4c-9a0284e658ca',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T20:24:05.504Z',
#   'updatedAt': '2020-03-30T20:24:05.504Z',
#   'floor': 3,
#   'content': '真是一個滿分的妹妹………',
#   'likeCount': 5353,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '中國醫藥大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'cdd73c45-2a6d-443e-9cdc-d8cefca1120e',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T21:30:37.743Z',
#   'updatedAt': '2020-03-30T21:30:37.743Z',
#   'floor': 4,
#   'content': '都辛苦了\n你是個很好的妹妹\n別給自己太大的壓力\n感覺妳已經很棒了',
#   'likeCount': 638,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '鯊魚養殖戶',
#   'department': 'chin_yu',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'a6134ff7-5421-49c8-a0ca-e14a82f899f3',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T21:34:10.255Z',
#   'updatedAt': '2020-03-30T21:34:10.255Z',
#   'floor': 5,
#   'content': '辛苦了，你很棒',
#   'likeCount': 181,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '新北倉鼠系',
#   'department': 'milk_0711',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '45093d81-a1a8-44a4-9cee-56faf333a103',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-30T23:32:35.230Z',
#   'updatedAt': '2020-03-30T23:32:35.230Z',
#   'floor': 6,
#   'content': '你是一個好妹妹，辛苦你了，要加油唷',
#   'likeCount': 201,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '中國文化大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'b8bd2d94-8643-431d-9b60-3ba0b924f020',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T00:05:07.517Z',
#   'updatedAt': '2020-03-31T00:05:07.517Z',
#   'floor': 7,
#   'withNickname': False,
#   'hiddenByAuthor': True,
#   'meta': {},
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': True,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'b2dcaebe-99ee-4930-aec9-11d5aa2d43b7',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T00:05:34.162Z',
#   'updatedAt': '2020-03-31T00:05:34.162Z',
#   'floor': 8,
#   'content': '辛苦妳了，妳哥哥也是\n\n加油加油努力過好每一天💪💪',
#   'likeCount': 138,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '高苑科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '9980882a-4621-4bf9-9261-b71d2cc1e3f4',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T00:43:26.471Z',
#   'updatedAt': '2020-03-31T00:43:26.471Z',
#   'floor': 9,
#   'content': '你很好！是哥哥的天使！更是哥哥的全部',
#   'likeCount': 260,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '僑光科技大學',
#   'department': 'okevin_d',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'aa00cdef-6fad-4269-839d-29ae439bd2cb',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T01:14:13.510Z',
#   'updatedAt': '2020-03-31T01:14:13.510Z',
#   'floor': 10,
#   'content': '我姐也是智能不足\n辛苦了～',
#   'likeCount': 148,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立交通大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '2595dd43-d933-46fe-8edb-0cf1b780fdf5',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T01:37:55.039Z',
#   'updatedAt': '2020-03-31T01:37:55.039Z',
#   'floor': 11,
#   'content': '辛苦妳了 妳最棒了QQ',
#   'likeCount': 65,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '耕莘健康管理專科學校',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'e94ae3ca-3666-43f6-953d-09be8a83d8fb',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T01:45:55.917Z',
#   'updatedAt': '2020-03-31T01:45:55.917Z',
#   'floor': 12,
#   'content': '哥哥一定很謝謝有你這個好妹妹❤️',
#   'likeCount': 110,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '致理科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'e161efd9-ac2e-4a65-994c-208024f64886',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T01:46:53.437Z',
#   'updatedAt': '2020-03-31T01:46:53.437Z',
#   'floor': 13,
#   'content': '真的你好棒！你也是一個很善良的人喔 跟你哥哥果然是最好的夥伴呢o(≧v≦)o',
#   'likeCount': 122,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '輔英科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '5bf9b416-1d24-4a30-943a-23bf125ecc66',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T02:01:54.018Z',
#   'updatedAt': '2020-03-31T02:01:54.018Z',
#   'floor': 14,
#   'content': '都辛苦了♡你真的很棒！',
#   'likeCount': 53,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立中央大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'b21f10f9-98ef-4fa8-a401-76c1ca07bbc8',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T02:13:22.608Z',
#   'updatedAt': '2020-03-31T02:13:22.608Z',
#   'floor': 15,
#   'content': '你是個好妹妹',
#   'likeCount': 46,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '高雄醫學大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'a33a29fc-c7f0-42b2-b043-5e0be7ead88b',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T02:23:10.263Z',
#   'updatedAt': '2020-03-31T02:23:10.263Z',
#   'floor': 16,
#   'content': '文筆好好\n妳是一個很棒的妹妹\n也謝謝妳的這篇文章\n讓人覺得心裡暖洋洋的\n妳們都是心地善良的小天使',
#   'likeCount': 307,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立政治大學',
#   'department': '法律研究所',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '1953b3a7-e185-481f-a33f-b056b1a1b874',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T02:40:51.653Z',
#   'updatedAt': '2020-03-31T02:40:51.653Z',
#   'floor': 17,
#   'content': '加油',
#   'likeCount': 25,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '臺北城市科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '13a14d36-225b-4b41-8424-599878a1cc53',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T02:52:05.512Z',
#   'updatedAt': '2020-03-31T02:52:05.512Z',
#   'floor': 18,
#   'content': '老闆⋯⋯我的早餐你怎麼加那麼多生洋蔥⋯⋯',
#   'likeCount': 202,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立中正大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '7703069e-527b-4b95-bcaf-87306dbc1d62',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:01:44.512Z',
#   'updatedAt': '2020-03-31T03:01:44.512Z',
#   'floor': 19,
#   'content': '只是喝杯奶茶怎麼沒味道...\n啊抱歉我眼淚滴太多了',
#   'likeCount': 169,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '致理科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '189548ff-c2d1-4bb0-be5c-ccdfaf555c9e',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:02:08.444Z',
#   'updatedAt': '2020-03-31T03:02:08.444Z',
#   'floor': 20,
#   'content': '看到標題以為是母湯的',
#   'likeCount': 130,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '長榮大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'd5002f85-36e8-4623-99c6-f211789260a2',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:07:17.609Z',
#   'updatedAt': '2020-03-31T03:07:17.609Z',
#   'floor': 21,
#   'content': '我的課本上都是我的淚😭',
#   'likeCount': 66,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立臺北商業大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'c36ad4f0-ae74-41d1-8523-092f07177879',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:07:17.884Z',
#   'updatedAt': '2020-03-31T03:07:17.884Z',
#   'floor': 22,
#   'content': '（抱',
#   'likeCount': 23,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '朝陽科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'b2bebbcf-f4c2-4684-9214-565311914b45',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:11:30.775Z',
#   'updatedAt': '2020-03-31T03:11:30.775Z',
#   'floor': 23,
#   'content': '好暖心喔！反而是當媽媽的怎麼都會把情緒發洩小孩身上 很舒壓？媽的！因為我也是被媽媽時常發洩情緒勒索我',
#   'likeCount': 92,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '健行科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'e9d6ae42-b3ae-42d1-9b24-d66919378251',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:12:37.710Z',
#   'updatedAt': '2020-03-31T03:12:37.710Z',
#   'floor': 24,
#   'content': '你真的好棒\n願世人能善待你們的溫柔善良',
#   'likeCount': 65,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '朝陽科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '4adde8af-4abc-498c-8c13-c3d8eab607a7',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:16:22.358Z',
#   'updatedAt': '2020-03-31T03:16:22.358Z',
#   'floor': 25,
#   'content': '校園裡面有你這麼溫暖的人真好🧡\n哥哥不幸中的大幸就是擁有你這個妹妹\n要好好繼續加油哦！',
#   'likeCount': 60,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立臺中科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'c6d9875e-5b8c-4901-8ab5-5a9e140cf1de',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:17:55.970Z',
#   'updatedAt': '2020-03-31T03:17:55.970Z',
#   'floor': 26,
#   'content': '妳也是善良溫暖的人呀☺️',
#   'likeCount': 39,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '長榮大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '7e5f5f1d-b220-41ff-bd37-3757b083a2f3',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:23:27.756Z',
#   'updatedAt': '2020-03-31T03:23:27.756Z',
#   'floor': 27,
#   'content': '辛苦你了！你要了解哥哥並不是你的責任，所以不要讓自己壓力太大！你的善良與愛，世界不會虧待你的🥰🥰😍😍',
#   'likeCount': 47,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '輔仁大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '8c24767b-9dab-4c28-9995-a4c7a8f4943b',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:28:12.458Z',
#   'updatedAt': '2020-03-31T03:28:12.458Z',
#   'floor': 28,
#   'content': '辛苦了！加油！妳很棒！',
#   'likeCount': 9,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立臺中科技大學',
#   'department': '應用英語系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '5903874d-7493-4ff7-b68f-09592c20d0a8',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:35:20.296Z',
#   'updatedAt': '2020-03-31T03:36:30.016Z',
#   'floor': 29,
#   'content': '我們無時無刻不在成長中，\n成長的每個階段，難免會有不同的想法，\n重要的是，後來的我們，成為了什麼樣子。\n\n不必太過在意曾經的想法\n因為現在的你，已經是個願意為人著想，溫暖而善良的人。我們喜歡你現在的樣子。未來會變得怎麼樣，我們不知道，但只要能記住現在的感覺，那就可以了。\n\n請愉快地小步躍著前行吧～',
#   'likeCount': 153,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '麻瓜燉雞',
#   'department': 'feya13',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'c8939fcc-41ec-4988-85d1-6ec150718005',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:40:51.862Z',
#   'updatedAt': '2020-03-31T03:40:51.862Z',
#   'floor': 30,
#   'content': '妹妹 很可以喔',
#   'likeCount': 8,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立高雄科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'fa35f5f2-1198-4b9e-b314-ab3577a9ee7e',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:46:56.225Z',
#   'updatedAt': '2020-03-31T03:46:56.225Z',
#   'floor': 31,
#   'content': 'B23 媽媽應該也很痛苦吧？\n光是照顧一個正常的孩子都足以讓父母崩潰了，何況是一個智能不足的小孩，我看過很多那樣的家庭，他們真的很辛苦，不論金錢、外人眼光還是什麼，總有一堆麻煩事等著他們😢😢',
#   'likeCount': 264,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '亞洲大學',
#   'department': '財務金融學系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '5b8005ca-848f-493a-89e5-cb850eaaac3d',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:54:55.281Z',
#   'updatedAt': '2020-03-31T03:54:55.281Z',
#   'floor': 32,
#   'content': '妳很棒',
#   'likeCount': 3,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '靜宜大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '1b31837c-3120-415d-b347-0377fb429dfe',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T03:59:56.504Z',
#   'updatedAt': '2020-03-31T04:00:20.136Z',
#   'floor': 33,
#   'content': '不知道為什麼 有些內容心境很像陽光普照電影的情節 我也是深入提到家人 情緒就會忍不住潰提',
#   'likeCount': 29,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立中興大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '3d54ba1d-03c8-4787-ab06-52189b0202f2',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:03:50.161Z',
#   'updatedAt': '2020-03-31T04:10:39.393Z',
#   'floor': 34,
#   'content': 'B33 我只是想把陽光讓給了弟弟……',
#   'likeCount': 23,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立虎尾科技大學',
#   'department': '動力機械工程系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '2542583a-818e-4488-8a5f-5ed8947bda31',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:05:04.858Z',
#   'updatedAt': '2020-03-31T04:05:04.858Z',
#   'floor': 35,
#   'content': '看標題以為你被怎麼了⋯',
#   'likeCount': 6,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '中國科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '05b97c9e-0860-418a-866b-334ee82c4817',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:09:17.857Z',
#   'updatedAt': '2020-03-31T04:09:17.857Z',
#   'floor': 36,
#   'content': '看完有種想抱著你說，你辛苦了的衝動。',
#   'likeCount': 8,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '別跟我搶餅乾',
#   'department': 'ghi159762',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '6def9ecc-d141-4161-9d8f-f341c609abcb',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:10:34.615Z',
#   'updatedAt': '2020-03-31T04:10:34.615Z',
#   'floor': 37,
#   'content': '我看到了天使(´⊙ω⊙`)',
#   'likeCount': 9,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '國立暨南國際大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '02384b93-2822-4927-8937-a09cfa83baba',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:15:52.287Z',
#   'updatedAt': '2020-03-31T04:15:52.287Z',
#   'floor': 38,
#   'content': 'B31 我只能說我長大才知道我媽真的超辛苦\n\n我是一個過動兒(小時候啦\n小時候造成我媽超多麻煩……(我媽是說很少發脾氣也只有我頑皮的上時候',
#   'likeCount': 28,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立虎尾科技大學',
#   'department': '動力機械工程系',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'f1ae9458-7c2e-4317-a48a-42179ed12aad',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:16:53.279Z',
#   'updatedAt': '2020-03-31T04:16:53.279Z',
#   'floor': 39,
#   'content': '真暖！好妹妹！！',
#   'likeCount': 3,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立臺灣大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '89a90c44-d69a-4bc9-bd59-113ac578b6ed',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:16:59.549Z',
#   'updatedAt': '2020-03-31T04:17:41.220Z',
#   'floor': 40,
#   'content': '也許不是滿分的妹妹\n但是在你哥哥眼中永遠都會是100分的家人\n哥哥會這樣就是命運\n難過就哭吧\n但還是希望妳能勇敢的陪伴哥哥走完餘生',
#   'likeCount': 71,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立交通大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '322b0f27-78e4-4ab3-a373-dbac46e83ff0',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:27:45.977Z',
#   'updatedAt': '2020-03-31T04:27:45.977Z',
#   'floor': 41,
#   'content': '這文筆好像在看以前國文課本上會出現的文章\n雖然我沒兄弟姊妹，但深刻的描繪看了還是讓我很有感觸很想哭',
#   'likeCount': 49,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '嶺東科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '049108f7-0d20-46f5-a511-b22250275241',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:28:31.334Z',
#   'updatedAt': '2020-03-31T04:28:31.334Z',
#   'floor': 42,
#   'content': 'Do you wanna build a snowman',
#   'likeCount': 39,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '國立清華大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '0d707505-6608-4d44-be4a-808444e3fc57',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:30:46.600Z',
#   'updatedAt': '2020-03-31T04:30:46.600Z',
#   'floor': 43,
#   'content': '看得好想哭 你真的是個好妹妹',
#   'likeCount': 8,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '世新大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'e77409d3-ef67-43b6-85bc-d5f46d97bbbc',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:32:49.332Z',
#   'updatedAt': '2020-03-31T04:32:49.332Z',
#   'floor': 44,
#   'content': '真的眼眶泛淚🥺🥺\n親情總是最容易觸犯淚腺的地方🥺',
#   'likeCount': 15,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '僑光科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'ac511e24-f222-472a-b83d-11124792d010',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:35:17.338Z',
#   'updatedAt': '2020-03-31T04:35:17.338Z',
#   'floor': 45,
#   'content': '我怎麼覺得你哥的智商比一堆發廢文的高很多',
#   'likeCount': 88,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '逢甲大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '11bc1066-b106-4fb9-8607-979ac26cba63',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:35:30.251Z',
#   'updatedAt': '2020-03-31T04:35:30.251Z',
#   'floor': 46,
#   'content': '你很棒你哥一定很開心有你這樣的妹妹💪',
#   'likeCount': 2,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'F',
#   'school': '僑光科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'caddd3db-ddc9-46eb-8c5b-0dc52803d191',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:36:50.158Z',
#   'updatedAt': '2020-03-31T04:36:50.158Z',
#   'floor': 47,
#   'content': '暖文',
#   'likeCount': 6,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '逢甲大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'e7621187-d72c-4af6-ae54-9c812eeb6f88',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:45:04.631Z',
#   'updatedAt': '2020-03-31T04:45:04.631Z',
#   'floor': 48,
#   'content': '給妳100分\n真的是一個好妹妹\n但自己壓力不要給自己太大\n加油～',
#   'likeCount': 6,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '中華醫事科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': '5264cddc-b36f-49fa-a6ec-3f11d7fdf7f4',
#   'anonymous': False,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:47:42.512Z',
#   'updatedAt': '2020-03-31T04:47:42.512Z',
#   'floor': 49,
#   'content': '他不笨他是我哥哥😭',
#   'likeCount': 38,
#   'withNickname': True,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '迷路的人',
#   'department': 'mim',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''},
#  {'id': 'fa502fe1-d279-4042-bb4a-4279f27a24e9',
#   'anonymous': True,
#   'postId': 233377179,
#   'createdAt': '2020-03-31T04:47:51.996Z',
#   'updatedAt': '2020-03-31T04:47:51.996Z',
#   'floor': 50,
#   'content': '哥哥加油！！！！！！',
#   'likeCount': 3,
#   'withNickname': False,
#   'hiddenByAuthor': False,
#   'meta': {},
#   'gender': 'M',
#   'school': '修平科技大學',
#   'host': False,
#   'reportReason': '',
#   'mediaMeta': [],
#   'hidden': False,
#   'inReview': False,
#   'reportReasonText': '',
#   'isSuspiciousAccount': False,
#   'postAvatar': ''}]

# %%
len(resp.json())
# Out:
# 50
